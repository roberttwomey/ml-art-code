# %% [markdown]
# <a href="https://colab.research.google.com/github/roberttwomey/ml-art-code-dev/blob/master/initro/MNIST_Python_Neural_Network_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### MNIST neural network from scratch

# %% [markdown]
# #### Fully Connected Layer (Linear Layer)

# %%
import numpy as np

class Linear():
    def __init__(self, in_size, out_size):
        self.W = np.random.randn(in_size, out_size) * 0.01
        self.b = np.zeros((1, out_size))
        self.params = [self.W, self.b]
        self.gradW = None
        self.gradB = None
        self.gradInput = None

    def forward(self, X):
        self.X = X
        self.output = np.dot(X, self.W) + self.b
        return self.output

    def backward(self, nextgrad):
        self.gradW = np.dot(self.X.T, nextgrad)
        self.gradB = np.sum(nextgrad, axis=0)
        self.gradInput = np.dot(nextgrad, self.W.T)
        return self.gradInput, [self.gradW, self.gradB]

# %%
np.random.seed(3)

# %% [markdown]
# #### Rectified Linear Activation Layer (ReLU)

# %%
class ReLU():
    def __init__(self):
        self.params = []
        self.gradInput = None

    def forward(self, X):
        self.output = np.maximum(X, 0)
        return self.output

    def backward(self, nextgrad):
        self.gradInput = nextgrad.copy()
        self.gradInput[self.output <=0] = 0
        return self.gradInput, []

# %% [markdown]
# #### Defining the softmax function

# %%
def softmax(x):
    exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
    out= exp_x / np.sum(exp_x, axis=1, keepdims=True)
    return out

# %% [markdown]
# #### Defining the Cross Entropy Loss

# %%
class CrossEntropy:
    def forward(self, X, y):
        self.m = y.shape[0]
        self.p = softmax(X)
        cross_entropy = -np.log(self.p[range(self.m), y])
        loss = cross_entropy[0] / self.m
        return loss

    def backward(self, X, y):
        y_idx = y.argmax()
        grad = softmax(X)
        grad[range(self.m), y] -= 1
        grad /= self.m
        return grad

# %% [markdown]
# #### Loading the MNIST dataset

# %%
from keras.datasets import mnist
# from keras.utils import np_utils


(train_features, train_targets), (test_features, test_targets) = mnist.load_data()


train_features = train_features.reshape(60000, 784)
print(train_features.shape)
test_features = test_features.reshape(10000, 784)
print(test_features.shape)


# # normalize inputs from 0-255 to 0-1
train_features = train_features / 255.0
test_features = test_features / 255.0

print(train_targets.shape)
print(test_targets.shape)

X_train = train_features
y_train = train_targets

X_val = test_features
y_val = test_targets
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# (60000, 784)
# (10000, 784)
# (60000,)
# (10000,)

# %%
# visualizing the first 10 images in the dataset and their labels
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 1))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(X_train[i].reshape(28, 28), cmap="gray")
    plt.axis('off')
plt.show()
print('label for each of the above image: %s' % (y_train[0:10]))
# Out:
# label for each of the above image: [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# #### Here, we define the container NN class that enables the forward prop and backward propagation of the entire network. Note, how this class enables us to add layers of different types and also correctly pass gradients using the chain rule.

# %%
class NN():
    def __init__(self, lossfunc=CrossEntropy()):
        self.params = []
        self.layers = []
        self.loss_func = lossfunc
        self.grads = []

    def add_layer(self, layer):
        self.layers.append(layer)
        self.params.append(layer.params)

    def forward(self, X):
        for layer in self.layers:
            X = layer.forward(X)
        return X

    def backward(self, nextgrad):
        self.clear_grad_param()
        for layer in reversed(self.layers):
            nextgrad, grad = layer.backward(nextgrad)
            self.grads.append(grad)
        return self.grads

    def train_step(self, X, y):
        out = self.forward(X)
        loss = self.loss_func.forward(out,y)
        nextgrad = self.loss_func.backward(out,y)
        l2 = self.backward(nextgrad)
        return loss, l2

    def predict(self, X):
        X = self.forward(X)
        return np.argmax(X, axis=1)

    def predict_scores(self, X):
        X = self.forward(X)
        return X

    def clear_grad_param(self):
        self.grads = []

# %% [markdown]
# #### Defining the update function (SGD with momentum)

# %%
def update_params(velocity, params, grads, learning_rate=0.01, mu=0.9):
    for v, p, g, in zip(velocity, params, reversed(grads)):
        for i in range(len(g)):
            v[i] = mu * v[i] + learning_rate * g[i]
            p[i] -= v[i]
            print('Max gradient value:',np.amax(v[i]))
            print('Gradient shape:',v[i].shape)

# %% [markdown]
# #### Defining a function which gives us the minibatches (both the datapoint and the corresponding label)

# %%
# get minibatches
def minibatch(X, y, minibatch_size):
    n = X.shape[0]
    minibatches = []
    permutation = np.random.permutation(X.shape[0])
    X = X[permutation]
    y = y[permutation]

    for i in range(0, n , minibatch_size):
        X_batch = X[i:i + minibatch_size, :]
        y_batch = y[i:i + minibatch_size, ]
        minibatches.append((X_batch, y_batch))

    return minibatches

# %% [markdown]
# #### The traning loop

# %%
def train(net, X_train, y_train, minibatch_size, epoch, learning_rate, mu=0.9, X_val=None, y_val=None):
    val_loss_epoch = []
    minibatches = minibatch(X_train, y_train, minibatch_size)
    minibatches_val = minibatch(X_val, y_val, minibatch_size)


    for i in range(epoch):
        loss_batch = []
        val_loss_batch = []
        velocity = []
        for param_layer in net.params:
            p = [np.zeros_like(param) for param in list(param_layer)]
            velocity.append(p)

        # iterate over mini batches
        for X_mini, y_mini in minibatches:
            loss, grads = net.train_step(X_mini, y_mini)
            loss_batch.append(loss)
            update_params(velocity, net.params, grads, learning_rate=learning_rate, mu=mu)

        for X_mini_val, y_mini_val in minibatches_val:
            val_loss, _ = net.train_step(X_mini, y_mini)
            val_loss_batch.append(val_loss)

        # accuracy of model at end of epoch after all mini batch updates
        m_train = X_train.shape[0]
        m_val = X_val.shape[0]
        y_train_pred = np.array([], dtype="int64")
        y_val_pred = np.array([], dtype="int64")
        y_train1 = []
        y_vall = []
        for i in range(0, m_train, minibatch_size):
            X_tr = X_train[i:i + minibatch_size, : ]
            y_tr = y_train[i:i + minibatch_size,]
            y_train1 = np.append(y_train1, y_tr)
            y_train_pred = np.append(y_train_pred, net.predict(X_tr))

        for i in range(0, m_val, minibatch_size):
            X_va = X_val[i:i + minibatch_size, : ]
            y_va = y_val[i:i + minibatch_size,]
            y_vall = np.append(y_vall, y_va)
            y_val_pred = np.append(y_val_pred, net.predict(X_va))

        train_acc = check_accuracy(y_train1, y_train_pred)
        val_acc = check_accuracy(y_vall, y_val_pred)

        mean_train_loss = sum(loss_batch) / float(len(loss_batch))
        mean_val_loss = sum(val_loss_batch) / float(len(val_loss_batch))

        val_loss_epoch.append(mean_val_loss)
        print("Loss = {0} | Training Accuracy = {1} | Val Loss = {2} | Val Accuracy = {3}".format(mean_train_loss, train_acc, mean_val_loss, val_acc))
    return net

# %% [markdown]
# #### Checking the accuracy of the model

# %%
def check_accuracy(y_true, y_pred):
    return np.mean(y_pred == y_true)

# %% [markdown]
# #### Invoking all that we have created until now

# %%
from random import shuffle

## input size
input_dim = X_train.shape[1]

## hyperparameters
iterations = 10
learning_rate = 0.1
hidden_nodes = 32
output_nodes = 10

## define neural net
nn = NN()
nn.add_layer(Linear(input_dim, hidden_nodes))
nn.add_layer(ReLU())
nn.add_layer(Linear(hidden_nodes, output_nodes))

nn = train(nn, X_train , y_train, minibatch_size=200, epoch=10, \
           learning_rate=learning_rate, X_val=X_val, y_val=y_val)
# Out:
# Streaming output truncated to the last 5000 lines.
# Gradient shape: (1, 32)
# Max gradient value: 0.006155735683346338
# Gradient shape: (32, 10)
# Max gradient value: 0.0008483303609863022
# Gradient shape: (1, 10)
# Max gradient value: 0.004890773494649446
# Gradient shape: (784, 32)
# Max gradient value: 0.004527725540265733
# Gradient shape: (1, 32)
# Max gradient value: 0.008448261272351276
# Gradient shape: (32, 10)
# Max gradient value: 0.0012152823458035761
# Gradient shape: (1, 10)
# Max gradient value: 0.004244485453166862
# Gradient shape: (784, 32)
# Max gradient value: 0.00414451414332451
# Gradient shape: (1, 32)
# Max gradient value: 0.00809164615505592
# Gradient shape: (32, 10)
# Max gradient value: 0.0014081695785495083
# Gradient shape: (1, 10)
# Max gradient value: 0.004143492737790024
# Gradient shape: (784, 32)
# Max gradient value: 0.003947255179514099
# Gradient shape: (1, 32)
# Max gradient value: 0.0071085248962377175
# Gradient shape: (32, 10)
# Max gradient value: 0.0018952685019822495
# Gradient shape: (1, 10)
# Max gradient value: 0.0036839772814356987
# Gradient shape: (784, 32)
# Max gradient value: 0.0033632042288191354
# Gradient shape: (1, 32)
# Max gradient value: 0.005610536034928742
# Gradient shape: (32, 10)
# Max gradient value: 0.0007955016600294396
# Gradient shape: (1, 10)
# Max gradient value: 0.0037583542003258807
# Gradient shape: (784, 32)
# Max gradient value: 0.003200801102126742
# Gradient shape: (1, 32)
# Max gradient value: 0.006030131478871224
# Gradient shape: (32, 10)
# Max gradient value: 0.0011313534783740135
# Gradient shape: (1, 10)
# Max gradient value: 0.003907504157226149
# Gradient shape: (784, 32)
# Max gradient value: 0.002413799691444148
# Gradient shape: (1, 32)
# Max gradient value: 0.012287049561596368
# Gradient shape: (32, 10)
# Max gradient value: 0.001959074146971603
# Gradient shape: (1, 10)
# Max gradient value: 0.0038067550428609095
# Gradient shape: (784, 32)
# Max gradient value: 0.003019627247995497
# Gradient shape: (1, 32)
# Max gradient value: 0.010568426083570014
# Gradient shape: (32, 10)
# Max gradient value: 0.0018403428246021266
# Gradient shape: (1, 10)
# Max gradient value: 0.003909391372292174
# Gradient shape: (784, 32)
# Max gradient value: 0.0038901732618588595
# Gradient shape: (1, 32)
# Max gradient value: 0.01061139966506877
# Gradient shape: (32, 10)
# Max gradient value: 0.0023291624077737
# Gradient shape: (1, 10)
# Max gradient value: 0.003526616093884168
# Gradient shape: (784, 32)
# Max gradient value: 0.0034557992062465544
# Gradient shape: (1, 32)
# Max gradient value: 0.009890735592968925
# Gradient shape: (32, 10)
# Max gradient value: 0.0026751980002513542
# Gradient shape: (1, 10)
# Max gradient value: 0.0035157885203790417
# Gradient shape: (784, 32)
# Max gradient value: 0.003393475525728841
# Gradient shape: (1, 32)
# Max gradient value: 0.006220086703963117
# Gradient shape: (32, 10)
# Max gradient value: 0.0014100669082196295
# Gradient shape: (1, 10)
# Max gradient value: 0.003791294532555813
# Gradient shape: (784, 32)
# Max gradient value: 0.003849897563555851
# Gradient shape: (1, 32)
# Max gradient value: 0.006019969778105313
# Gradient shape: (32, 10)
# Max gradient value: 0.0017300086171837142
# Gradient shape: (1, 10)
# Max gradient value: 0.0034344025739022964
# Gradient shape: (784, 32)
# Max gradient value: 0.003040224311656547
# Gradient shape: (1, 32)
# Max gradient value: 0.005682972912800576
# Gradient shape: (32, 10)
# Max gradient value: 0.001763118606997347
# Gradient shape: (1, 10)
# Max gradient value: 0.003505072346159142
# Gradient shape: (784, 32)
# Max gradient value: 0.0031054522161269365
# Gradient shape: (1, 32)
# Max gradient value: 0.005042741599742113
# Gradient shape: (32, 10)
# Max gradient value: 0.0012300461393397264
# Gradient shape: (1, 10)
# Max gradient value: 0.004360142449112393
# Gradient shape: (784, 32)
# Max gradient value: 0.005147543134279052
# Gradient shape: (1, 32)
# Max gradient value: 0.006252353874786208
# Gradient shape: (32, 10)
# Max gradient value: 0.001407647800718173
# Gradient shape: (1, 10)
# Max gradient value: 0.004036974717537528
# Gradient shape: (784, 32)
# Max gradient value: 0.004718071063733956
# Gradient shape: (1, 32)
# Max gradient value: 0.00637645303298328
# Gradient shape: (32, 10)
# Max gradient value: 0.0016241217554062244
# Gradient shape: (1, 10)
# Max gradient value: 0.003052028363834496
# Gradient shape: (784, 32)
# Max gradient value: 0.0030506959775741275
# Gradient shape: (1, 32)
# Max gradient value: 0.010441561769156109
# Gradient shape: (32, 10)
# Max gradient value: 0.0024991953543162097
# Gradient shape: (1, 10)
# Max gradient value: 0.003185783815937103
# Gradient shape: (784, 32)
# Max gradient value: 0.003173013711652125
# Gradient shape: (1, 32)
# Max gradient value: 0.006627998067109419
# Gradient shape: (32, 10)
# Max gradient value: 0.0019069990871221313
# Gradient shape: (1, 10)
# Max gradient value: 0.0040439312762809475
# Gradient shape: (784, 32)
# Max gradient value: 0.0033278029485116333
# Gradient shape: (1, 32)
# Max gradient value: 0.007996671574239582
# Gradient shape: (32, 10)
# Max gradient value: 0.002968529114357519
# Gradient shape: (1, 10)
# Max gradient value: 0.004353508965104565
# Gradient shape: (784, 32)
# Max gradient value: 0.0050411005863730445
# Gradient shape: (1, 32)
# Max gradient value: 0.01026191804643121
# Gradient shape: (32, 10)
# Max gradient value: 0.0031917902960420476
# Gradient shape: (1, 10)
# Max gradient value: 0.003770000570928245
# Gradient shape: (784, 32)
# Max gradient value: 0.004362873367671387
# Gradient shape: (1, 32)
# Max gradient value: 0.01175010014731539
# Gradient shape: (32, 10)
# Max gradient value: 0.0033330416639395025
# Gradient shape: (1, 10)
# Max gradient value: 0.004006129799946375
# Gradient shape: (784, 32)
# Max gradient value: 0.003441947074341829
# Gradient shape: (1, 32)
# Max gradient value: 0.01508625364253595
# Gradient shape: (32, 10)
# Max gradient value: 0.0034818972474299765
# Gradient shape: (1, 10)
# Max gradient value: 0.003532634722888937
# Gradient shape: (784, 32)
# Max gradient value: 0.002532866032158085
# Gradient shape: (1, 32)
# Max gradient value: 0.01261970810495623
# Gradient shape: (32, 10)
# Max gradient value: 0.002660235419929228
# Gradient shape: (1, 10)
# Max gradient value: 0.003178768077398449
# Gradient shape: (784, 32)
# Max gradient value: 0.0023649947033781895
# Gradient shape: (1, 32)
# Max gradient value: 0.009876768758851708
# Gradient shape: (32, 10)
# Max gradient value: 0.0019330941856175133
# Gradient shape: (1, 10)
# Max gradient value: 0.0035791027189639077
# Gradient shape: (784, 32)
# Max gradient value: 0.0027366646745499604
# Gradient shape: (1, 32)
# Max gradient value: 0.01045067041817451
# Gradient shape: (32, 10)
# Max gradient value: 0.0021178156847462934
# Gradient shape: (1, 10)
# Loss = 0.0004680338712392785 | Training Accuracy = 0.9744166666666667 | Val Loss = 4.0399317981759166e-05 | Val Accuracy = 0.9633
# Max gradient value: 0.0033320633908770396
# Gradient shape: (784, 32)
# Max gradient value: 0.003746440794232822
# Gradient shape: (1, 32)
# Max gradient value: 0.006166427507879375
# Gradient shape: (32, 10)
# Max gradient value: 0.0013349772089334229
# Gradient shape: (1, 10)
# Max gradient value: 0.0035912287704380846
# Gradient shape: (784, 32)
# Max gradient value: 0.004292263425072542
# Gradient shape: (1, 32)
# Max gradient value: 0.006222427996483856
# Gradient shape: (32, 10)
# Max gradient value: 0.001461018275469918
# Gradient shape: (1, 10)
# Max gradient value: 0.003254587443113153
# Gradient shape: (784, 32)
# Max gradient value: 0.004034899555907524
# Gradient shape: (1, 32)
# Max gradient value: 0.00739432032594245
# Gradient shape: (32, 10)
# Max gradient value: 0.0017006581021673654
# Gradient shape: (1, 10)
# Max gradient value: 0.0036100593664454895
# Gradient shape: (784, 32)
# Max gradient value: 0.0041099940209932
# Gradient shape: (1, 32)
# Max gradient value: 0.008409439916552883
# Gradient shape: (32, 10)
# Max gradient value: 0.001664956883625143
# Gradient shape: (1, 10)
# Max gradient value: 0.002514538868586005
# Gradient shape: (784, 32)
# Max gradient value: 0.0030720223648409615
# Gradient shape: (1, 32)
# Max gradient value: 0.0084663559453636
# Gradient shape: (32, 10)
# Max gradient value: 0.001975016216023826
# Gradient shape: (1, 10)
# Max gradient value: 0.0026319206328988508
# Gradient shape: (784, 32)
# Max gradient value: 0.0024908514484444613
# Gradient shape: (1, 32)
# Max gradient value: 0.008572830001095582
# Gradient shape: (32, 10)
# Max gradient value: 0.001780061559990946
# Gradient shape: (1, 10)
# Max gradient value: 0.002459279155310793
# Gradient shape: (784, 32)
# Max gradient value: 0.002137938719935629
# Gradient shape: (1, 32)
# Max gradient value: 0.007841998686467764
# Gradient shape: (32, 10)
# Max gradient value: 0.0015025017281454199
# Gradient shape: (1, 10)
# Max gradient value: 0.0022648164390391403
# Gradient shape: (784, 32)
# Max gradient value: 0.002272320366833288
# Gradient shape: (1, 32)
# Max gradient value: 0.008608418686126872
# Gradient shape: (32, 10)
# Max gradient value: 0.001720556515488606
# Gradient shape: (1, 10)
# Max gradient value: 0.002606318443825519
# Gradient shape: (784, 32)
# Max gradient value: 0.002362693877009757
# Gradient shape: (1, 32)
# Max gradient value: 0.006722611627528117
# Gradient shape: (32, 10)
# Max gradient value: 0.0014188581008906806
# Gradient shape: (1, 10)
# Max gradient value: 0.0023350685883334844
# Gradient shape: (784, 32)
# Max gradient value: 0.002402160416008589
# Gradient shape: (1, 32)
# Max gradient value: 0.005263155111935097
# Gradient shape: (32, 10)
# Max gradient value: 0.0007747015785665212
# Gradient shape: (1, 10)
# Max gradient value: 0.0026740754428370077
# Gradient shape: (784, 32)
# Max gradient value: 0.002735432520929753
# Gradient shape: (1, 32)
# Max gradient value: 0.006446941612301175
# Gradient shape: (32, 10)
# Max gradient value: 0.0010640260597132565
# Gradient shape: (1, 10)
# Max gradient value: 0.002873571679366082
# Gradient shape: (784, 32)
# Max gradient value: 0.002532137356840262
# Gradient shape: (1, 32)
# Max gradient value: 0.00980814454372621
# Gradient shape: (32, 10)
# Max gradient value: 0.0021043223704064066
# Gradient shape: (1, 10)
# Max gradient value: 0.003571142010397102
# Gradient shape: (784, 32)
# Max gradient value: 0.0029368480168914064
# Gradient shape: (1, 32)
# Max gradient value: 0.012798085930473902
# Gradient shape: (32, 10)
# Max gradient value: 0.0027065679166053407
# Gradient shape: (1, 10)
# Max gradient value: 0.0035129823580869477
# Gradient shape: (784, 32)
# Max gradient value: 0.0032457791773105107
# Gradient shape: (1, 32)
# Max gradient value: 0.010927431400245817
# Gradient shape: (32, 10)
# Max gradient value: 0.0023451862926989015
# Gradient shape: (1, 10)
# Max gradient value: 0.00278269777017381
# Gradient shape: (784, 32)
# Max gradient value: 0.0031055905938900713
# Gradient shape: (1, 32)
# Max gradient value: 0.008325774605589871
# Gradient shape: (32, 10)
# Max gradient value: 0.002005308814678688
# Gradient shape: (1, 10)
# Max gradient value: 0.0028457901020242904
# Gradient shape: (784, 32)
# Max gradient value: 0.003445848647738313
# Gradient shape: (1, 32)
# Max gradient value: 0.006332061811984204
# Gradient shape: (32, 10)
# Max gradient value: 0.0022566031918073446
# Gradient shape: (1, 10)
# Max gradient value: 0.0030282179807617033
# Gradient shape: (784, 32)
# Max gradient value: 0.002949789120080538
# Gradient shape: (1, 32)
# Max gradient value: 0.005956242931417211
# Gradient shape: (32, 10)
# Max gradient value: 0.001906519509525483
# Gradient shape: (1, 10)
# Max gradient value: 0.002857530647852317
# Gradient shape: (784, 32)
# Max gradient value: 0.0031998152169545897
# Gradient shape: (1, 32)
# Max gradient value: 0.005210081183436074
# Gradient shape: (32, 10)
# Max gradient value: 0.001731568107702827
# Gradient shape: (1, 10)
# Max gradient value: 0.002735169415466885
# Gradient shape: (784, 32)
# Max gradient value: 0.0029926261098581386
# Gradient shape: (1, 32)
# Max gradient value: 0.006262369052040723
# Gradient shape: (32, 10)
# Max gradient value: 0.0017709179529236333
# Gradient shape: (1, 10)
# Max gradient value: 0.002123729814389088
# Gradient shape: (784, 32)
# Max gradient value: 0.002373477397199724
# Gradient shape: (1, 32)
# Max gradient value: 0.005063075112279356
# Gradient shape: (32, 10)
# Max gradient value: 0.0010968920569498846
# Gradient shape: (1, 10)
# Max gradient value: 0.002733214120773713
# Gradient shape: (784, 32)
# Max gradient value: 0.002274441422286648
# Gradient shape: (1, 32)
# Max gradient value: 0.006152362530794301
# Gradient shape: (32, 10)
# Max gradient value: 0.0011562237559358934
# Gradient shape: (1, 10)
# Max gradient value: 0.0032175395641031368
# Gradient shape: (784, 32)
# Max gradient value: 0.0031561718794287648
# Gradient shape: (1, 32)
# Max gradient value: 0.010212991477802458
# Gradient shape: (32, 10)
# Max gradient value: 0.002491983908415832
# Gradient shape: (1, 10)
# Max gradient value: 0.004084550941295179
# Gradient shape: (784, 32)
# Max gradient value: 0.002923667157829689
# Gradient shape: (1, 32)
# Max gradient value: 0.012238121957404601
# Gradient shape: (32, 10)
# Max gradient value: 0.0030909963736722866
# Gradient shape: (1, 10)
# Max gradient value: 0.00463848373618052
# Gradient shape: (784, 32)
# Max gradient value: 0.0035836131876948113
# Gradient shape: (1, 32)
# Max gradient value: 0.011070078090932531
# Gradient shape: (32, 10)
# Max gradient value: 0.0027943123986464693
# Gradient shape: (1, 10)
# Max gradient value: 0.004175097661029841
# Gradient shape: (784, 32)
# Max gradient value: 0.003497074851967665
# Gradient shape: (1, 32)
# Max gradient value: 0.011518429383643397
# Gradient shape: (32, 10)
# Max gradient value: 0.0031043754852561794
# Gradient shape: (1, 10)
# Max gradient value: 0.0037621011545054556
# Gradient shape: (784, 32)
# Max gradient value: 0.0032426720455412954
# Gradient shape: (1, 32)
# Max gradient value: 0.012280113181643033
# Gradient shape: (32, 10)
# Max gradient value: 0.0031535680384461922
# Gradient shape: (1, 10)
# Max gradient value: 0.0031722773412843227
# Gradient shape: (784, 32)
# Max gradient value: 0.003062078519869406
# Gradient shape: (1, 32)
# Max gradient value: 0.009684287463183491
# Gradient shape: (32, 10)
# Max gradient value: 0.002896225368731642
# Gradient shape: (1, 10)
# Max gradient value: 0.003000997039838548
# Gradient shape: (784, 32)
# Max gradient value: 0.0026981325272414677
# Gradient shape: (1, 32)
# Max gradient value: 0.0071006296320032655
# Gradient shape: (32, 10)
# Max gradient value: 0.0023297160245680094
# Gradient shape: (1, 10)
# Max gradient value: 0.0028123088299750482
# Gradient shape: (784, 32)
# Max gradient value: 0.0027223600948354776
# Gradient shape: (1, 32)
# Max gradient value: 0.006825855244895535
# Gradient shape: (32, 10)
# Max gradient value: 0.0020635926649196687
# Gradient shape: (1, 10)
# Max gradient value: 0.0032129526929270337
# Gradient shape: (784, 32)
# Max gradient value: 0.002619108165943335
# Gradient shape: (1, 32)
# Max gradient value: 0.005760972733844251
# Gradient shape: (32, 10)
# Max gradient value: 0.0015541604473754333
# Gradient shape: (1, 10)
# Max gradient value: 0.0031003776924910303
# Gradient shape: (784, 32)
# Max gradient value: 0.0021487231764406958
# Gradient shape: (1, 32)
# Max gradient value: 0.005402699860374354
# Gradient shape: (32, 10)
# Max gradient value: 0.0005174565343737056
# Gradient shape: (1, 10)
# Max gradient value: 0.003067078995173747
# Gradient shape: (784, 32)
# Max gradient value: 0.002134559278273044
# Gradient shape: (1, 32)
# Max gradient value: 0.005952214727818094
# Gradient shape: (32, 10)
# Max gradient value: 0.0011156589181503026
# Gradient shape: (1, 10)
# Max gradient value: 0.003389952122836807
# Gradient shape: (784, 32)
# Max gradient value: 0.003001700009892216
# Gradient shape: (1, 32)
# Max gradient value: 0.010545936231360825
# Gradient shape: (32, 10)
# Max gradient value: 0.0019083124133788272
# Gradient shape: (1, 10)
# Max gradient value: 0.0037705872143440626
# Gradient shape: (784, 32)
# Max gradient value: 0.00310723263703458
# Gradient shape: (1, 32)
# Max gradient value: 0.012376573402611796
# Gradient shape: (32, 10)
# Max gradient value: 0.0024684461304093465
# Gradient shape: (1, 10)
# Max gradient value: 0.0028855795073836313
# Gradient shape: (784, 32)
# Max gradient value: 0.002572309388520455
# Gradient shape: (1, 32)
# Max gradient value: 0.012251397332561855
# Gradient shape: (32, 10)
# Max gradient value: 0.0016894679086085986
# Gradient shape: (1, 10)
# Max gradient value: 0.0033597323973386306
# Gradient shape: (784, 32)
# Max gradient value: 0.0030065409811665996
# Gradient shape: (1, 32)
# Max gradient value: 0.010731868049265845
# Gradient shape: (32, 10)
# Max gradient value: 0.001932319052399305
# Gradient shape: (1, 10)
# Max gradient value: 0.0033130774552721635
# Gradient shape: (784, 32)
# Max gradient value: 0.0027993058028520606
# Gradient shape: (1, 32)
# Max gradient value: 0.009702572751511027
# Gradient shape: (32, 10)
# Max gradient value: 0.0014098319932639772
# Gradient shape: (1, 10)
# Max gradient value: 0.003612862194068349
# Gradient shape: (784, 32)
# Max gradient value: 0.003660015351013999
# Gradient shape: (1, 32)
# Max gradient value: 0.008785064940147892
# Gradient shape: (32, 10)
# Max gradient value: 0.0020390591330510604
# Gradient shape: (1, 10)
# Max gradient value: 0.0033604920234533197
# Gradient shape: (784, 32)
# Max gradient value: 0.003375520774714967
# Gradient shape: (1, 32)
# Max gradient value: 0.00890725231507481
# Gradient shape: (32, 10)
# Max gradient value: 0.002343466789218902
# Gradient shape: (1, 10)
# Max gradient value: 0.0029227452418197383
# Gradient shape: (784, 32)
# Max gradient value: 0.002960484913618682
# Gradient shape: (1, 32)
# Max gradient value: 0.007800919621201396
# Gradient shape: (32, 10)
# Max gradient value: 0.00235499556570667
# Gradient shape: (1, 10)
# Max gradient value: 0.003013971191591913
# Gradient shape: (784, 32)
# Max gradient value: 0.0034259677275922684
# Gradient shape: (1, 32)
# Max gradient value: 0.00772076041152695
# Gradient shape: (32, 10)
# Max gradient value: 0.0029072161698826316
# Gradient shape: (1, 10)
# Max gradient value: 0.002564135759459508
# Gradient shape: (784, 32)
# Max gradient value: 0.002551631347576657
# Gradient shape: (1, 32)
# Max gradient value: 0.004493961168759195
# Gradient shape: (32, 10)
# Max gradient value: 0.0014609045539184485
# Gradient shape: (1, 10)
# Max gradient value: 0.002981082834697193
# Gradient shape: (784, 32)
# Max gradient value: 0.0026644615696195515
# Gradient shape: (1, 32)
# Max gradient value: 0.005857964623770225
# Gradient shape: (32, 10)
# Max gradient value: 0.0017994543368954126
# Gradient shape: (1, 10)
# Max gradient value: 0.0027586997377604177
# Gradient shape: (784, 32)
# Max gradient value: 0.0028528045938489947
# Gradient shape: (1, 32)
# Max gradient value: 0.006647452096151562
# Gradient shape: (32, 10)
# Max gradient value: 0.0015218146746168683
# Gradient shape: (1, 10)
# Max gradient value: 0.002792077134592693
# Gradient shape: (784, 32)
# Max gradient value: 0.003245773160286865
# Gradient shape: (1, 32)
# Max gradient value: 0.006250394373150236
# Gradient shape: (32, 10)
# Max gradient value: 0.0014444624937489732
# Gradient shape: (1, 10)
# Max gradient value: 0.0027883909110444647
# Gradient shape: (784, 32)
# Max gradient value: 0.0034259571548942735
# Gradient shape: (1, 32)
# Max gradient value: 0.005446949099412807
# Gradient shape: (32, 10)
# Max gradient value: 0.0009523684871246866
# Gradient shape: (1, 10)
# Max gradient value: 0.0026210261032405474
# Gradient shape: (784, 32)
# Max gradient value: 0.0036119316439467766
# Gradient shape: (1, 32)
# Max gradient value: 0.005358183533699117
# Gradient shape: (32, 10)
# Max gradient value: 0.001261034246397543
# Gradient shape: (1, 10)
# Max gradient value: 0.002388786218017767
# Gradient shape: (784, 32)
# Max gradient value: 0.0032034041790947724
# Gradient shape: (1, 32)
# Max gradient value: 0.005078954562142755
# Gradient shape: (32, 10)
# Max gradient value: 0.0012116322549829866
# Gradient shape: (1, 10)
# Max gradient value: 0.0029416282166228637
# Gradient shape: (784, 32)
# Max gradient value: 0.004033890248674843
# Gradient shape: (1, 32)
# Max gradient value: 0.007115740059630157
# Gradient shape: (32, 10)
# Max gradient value: 0.0017652744092088632
# Gradient shape: (1, 10)
# Max gradient value: 0.0035891759264614002
# Gradient shape: (784, 32)
# Max gradient value: 0.0044731983892113214
# Gradient shape: (1, 32)
# Max gradient value: 0.006707776355590903
# Gradient shape: (32, 10)
# Max gradient value: 0.0016296278919409337
# Gradient shape: (1, 10)
# Max gradient value: 0.003442954877862484
# Gradient shape: (784, 32)
# Max gradient value: 0.0044248439642482285
# Gradient shape: (1, 32)
# Max gradient value: 0.010381616827288873
# Gradient shape: (32, 10)
# Max gradient value: 0.002634773188977895
# Gradient shape: (1, 10)
# Max gradient value: 0.0031302741281608332
# Gradient shape: (784, 32)
# Max gradient value: 0.0031756787677789202
# Gradient shape: (1, 32)
# Max gradient value: 0.008779906405551284
# Gradient shape: (32, 10)
# Max gradient value: 0.0016787477684956078
# Gradient shape: (1, 10)
# Max gradient value: 0.004007411558005064
# Gradient shape: (784, 32)
# Max gradient value: 0.0035472486306532196
# Gradient shape: (1, 32)
# Max gradient value: 0.00722458631693932
# Gradient shape: (32, 10)
# Max gradient value: 0.0016638771290072448
# Gradient shape: (1, 10)
# Max gradient value: 0.004141419940293925
# Gradient shape: (784, 32)
# Max gradient value: 0.0034095387564923654
# Gradient shape: (1, 32)
# Max gradient value: 0.006603236211986506
# Gradient shape: (32, 10)
# Max gradient value: 0.0012169173369453853
# Gradient shape: (1, 10)
# Max gradient value: 0.004130614931812231
# Gradient shape: (784, 32)
# Max gradient value: 0.003196989399886805
# Gradient shape: (1, 32)
# Max gradient value: 0.0080126870662234
# Gradient shape: (32, 10)
# Max gradient value: 0.0013905352856359182
# Gradient shape: (1, 10)
# Max gradient value: 0.004084476434323561
# Gradient shape: (784, 32)
# Max gradient value: 0.0032024505826609147
# Gradient shape: (1, 32)
# Max gradient value: 0.008753032508755842
# Gradient shape: (32, 10)
# Max gradient value: 0.0013208722537050238
# Gradient shape: (1, 10)
# Max gradient value: 0.003650439640075807
# Gradient shape: (784, 32)
# Max gradient value: 0.0029903775622484663
# Gradient shape: (1, 32)
# Max gradient value: 0.009273860708632087
# Gradient shape: (32, 10)
# Max gradient value: 0.0021485781428251445
# Gradient shape: (1, 10)
# Max gradient value: 0.0031225139940271734
# Gradient shape: (784, 32)
# Max gradient value: 0.003429009667002785
# Gradient shape: (1, 32)
# Max gradient value: 0.014930409384349173
# Gradient shape: (32, 10)
# Max gradient value: 0.004040142621609964
# Gradient shape: (1, 10)
# Max gradient value: 0.003600523179947573
# Gradient shape: (784, 32)
# Max gradient value: 0.0039018938516361583
# Gradient shape: (1, 32)
# Max gradient value: 0.012334343345937587
# Gradient shape: (32, 10)
# Max gradient value: 0.0035117064099329637
# Gradient shape: (1, 10)
# Max gradient value: 0.003907657534817185
# Gradient shape: (784, 32)
# Max gradient value: 0.00423231563713177
# Gradient shape: (1, 32)
# Max gradient value: 0.012227492566602074
# Gradient shape: (32, 10)
# Max gradient value: 0.0036529878707409996
# Gradient shape: (1, 10)
# Max gradient value: 0.0034266534741553114
# Gradient shape: (784, 32)
# Max gradient value: 0.0035734146643115255
# Gradient shape: (1, 32)
# Max gradient value: 0.010755562229823391
# Gradient shape: (32, 10)
# Max gradient value: 0.002728117289238542
# Gradient shape: (1, 10)
# Max gradient value: 0.002916472636114623
# Gradient shape: (784, 32)
# Max gradient value: 0.003055345590123447
# Gradient shape: (1, 32)
# Max gradient value: 0.009373706014321264
# Gradient shape: (32, 10)
# Max gradient value: 0.002235530981651781
# Gradient shape: (1, 10)
# Max gradient value: 0.0024744125852661863
# Gradient shape: (784, 32)
# Max gradient value: 0.002358682872548771
# Gradient shape: (1, 32)
# Max gradient value: 0.0073911580084125615
# Gradient shape: (32, 10)
# Max gradient value: 0.001996372420066163
# Gradient shape: (1, 10)
# Max gradient value: 0.002435212285919456
# Gradient shape: (784, 32)
# Max gradient value: 0.0021107430715936633
# Gradient shape: (1, 32)
# Max gradient value: 0.005933803247792725
# Gradient shape: (32, 10)
# Max gradient value: 0.0014070808343205864
# Gradient shape: (1, 10)
# Max gradient value: 0.003082053807802806
# Gradient shape: (784, 32)
# Max gradient value: 0.002467181173622422
# Gradient shape: (1, 32)
# Max gradient value: 0.008866051896758743
# Gradient shape: (32, 10)
# Max gradient value: 0.0022504413169183116
# Gradient shape: (1, 10)
# Max gradient value: 0.0037902041144162726
# Gradient shape: (784, 32)
# Max gradient value: 0.0035803768701265196
# Gradient shape: (1, 32)
# Max gradient value: 0.010061164900654493
# Gradient shape: (32, 10)
# Max gradient value: 0.002874420757517776
# Gradient shape: (1, 10)
# Max gradient value: 0.0038974454060075377
# Gradient shape: (784, 32)
# Max gradient value: 0.004037637038412683
# Gradient shape: (1, 32)
# Max gradient value: 0.008222289816971845
# Gradient shape: (32, 10)
# Max gradient value: 0.002339125135933699
# Gradient shape: (1, 10)
# Max gradient value: 0.0031801994822401804
# Gradient shape: (784, 32)
# Max gradient value: 0.003613242520207048
# Gradient shape: (1, 32)
# Max gradient value: 0.007411047343436579
# Gradient shape: (32, 10)
# Max gradient value: 0.002254100286800892
# Gradient shape: (1, 10)
# Max gradient value: 0.0035608019530149627
# Gradient shape: (784, 32)
# Max gradient value: 0.0022620858846931005
# Gradient shape: (1, 32)
# Max gradient value: 0.010317728865806081
# Gradient shape: (32, 10)
# Max gradient value: 0.0015453837224748855
# Gradient shape: (1, 10)
# Max gradient value: 0.0028741966977557246
# Gradient shape: (784, 32)
# Max gradient value: 0.003006280861896397
# Gradient shape: (1, 32)
# Max gradient value: 0.008537180641586251
# Gradient shape: (32, 10)
# Max gradient value: 0.0021221518091701507
# Gradient shape: (1, 10)
# Max gradient value: 0.003283391232127954
# Gradient shape: (784, 32)
# Max gradient value: 0.003907845276927297
# Gradient shape: (1, 32)
# Max gradient value: 0.01037753213606615
# Gradient shape: (32, 10)
# Max gradient value: 0.0020243692230577782
# Gradient shape: (1, 10)
# Max gradient value: 0.0027011699929605716
# Gradient shape: (784, 32)
# Max gradient value: 0.003182491988261427
# Gradient shape: (1, 32)
# Max gradient value: 0.006704742049177045
# Gradient shape: (32, 10)
# Max gradient value: 0.0010542891904612782
# Gradient shape: (1, 10)
# Max gradient value: 0.002831386410860602
# Gradient shape: (784, 32)
# Max gradient value: 0.00291162610149161
# Gradient shape: (1, 32)
# Max gradient value: 0.006518541000682082
# Gradient shape: (32, 10)
# Max gradient value: 0.0013823965638433302
# Gradient shape: (1, 10)
# Max gradient value: 0.003545357352724699
# Gradient shape: (784, 32)
# Max gradient value: 0.0034624839748175675
# Gradient shape: (1, 32)
# Max gradient value: 0.012411605877196091
# Gradient shape: (32, 10)
# Max gradient value: 0.0027963018336639865
# Gradient shape: (1, 10)
# Max gradient value: 0.004194973030722361
# Gradient shape: (784, 32)
# Max gradient value: 0.004520988306202299
# Gradient shape: (1, 32)
# Max gradient value: 0.0179900404859292
# Gradient shape: (32, 10)
# Max gradient value: 0.004167165458495859
# Gradient shape: (1, 10)
# Max gradient value: 0.00744463597279984
# Gradient shape: (784, 32)
# Max gradient value: 0.008298051047182533
# Gradient shape: (1, 32)
# Max gradient value: 0.02185082386036915
# Gradient shape: (32, 10)
# Max gradient value: 0.0052639672791807745
# Gradient shape: (1, 10)
# Max gradient value: 0.007191566576780378
# Gradient shape: (784, 32)
# Max gradient value: 0.009044208020064774
# Gradient shape: (1, 32)
# Max gradient value: 0.02249588863700709
# Gradient shape: (32, 10)
# Max gradient value: 0.006345157857771359
# Gradient shape: (1, 10)
# Max gradient value: 0.006814324850912927
# Gradient shape: (784, 32)
# Max gradient value: 0.008554185392235873
# Gradient shape: (1, 32)
# Max gradient value: 0.014344821925352415
# Gradient shape: (32, 10)
# Max gradient value: 0.005003192686146064
# Gradient shape: (1, 10)
# Max gradient value: 0.0056055579581792015
# Gradient shape: (784, 32)
# Max gradient value: 0.007007854343282641
# Gradient shape: (1, 32)
# Max gradient value: 0.009894627711819112
# Gradient shape: (32, 10)
# Max gradient value: 0.00368346510928666
# Gradient shape: (1, 10)
# Max gradient value: 0.005003297710385099
# Gradient shape: (784, 32)
# Max gradient value: 0.005924345577229166
# Gradient shape: (1, 32)
# Max gradient value: 0.008098878769605133
# Gradient shape: (32, 10)
# Max gradient value: 0.00260235831877585
# Gradient shape: (1, 10)
# Max gradient value: 0.004251935512101766
# Gradient shape: (784, 32)
# Max gradient value: 0.004797009496336323
# Gradient shape: (1, 32)
# Max gradient value: 0.00702300454788679
# Gradient shape: (32, 10)
# Max gradient value: 0.0015071543939755528
# Gradient shape: (1, 10)
# Max gradient value: 0.0038344325546311306
# Gradient shape: (784, 32)
# Max gradient value: 0.0042173236077836535
# Gradient shape: (1, 32)
# Max gradient value: 0.006853626198828558
# Gradient shape: (32, 10)
# Max gradient value: 0.0012343965854481826
# Gradient shape: (1, 10)
# Max gradient value: 0.002737450726669195
# Gradient shape: (784, 32)
# Max gradient value: 0.0027136187132302276
# Gradient shape: (1, 32)
# Max gradient value: 0.005955940619555457
# Gradient shape: (32, 10)
# Max gradient value: 0.0011847174273743473
# Gradient shape: (1, 10)
# Max gradient value: 0.00249676361128747
# Gradient shape: (784, 32)
# Max gradient value: 0.002016972893049934
# Gradient shape: (1, 32)
# Max gradient value: 0.0069279126441331804
# Gradient shape: (32, 10)
# Max gradient value: 0.0014247786545944492
# Gradient shape: (1, 10)
# Max gradient value: 0.003035670042525652
# Gradient shape: (784, 32)
# Max gradient value: 0.0022910087816779053
# Gradient shape: (1, 32)
# Max gradient value: 0.006215807087507508
# Gradient shape: (32, 10)
# Max gradient value: 0.0013157967106926342
# Gradient shape: (1, 10)
# Max gradient value: 0.0028099709011785803
# Gradient shape: (784, 32)
# Max gradient value: 0.0031149327758632985
# Gradient shape: (1, 32)
# Max gradient value: 0.008217225981231993
# Gradient shape: (32, 10)
# Max gradient value: 0.0015973770526184251
# Gradient shape: (1, 10)
# Max gradient value: 0.0029670567700239296
# Gradient shape: (784, 32)
# Max gradient value: 0.0037288045421701873
# Gradient shape: (1, 32)
# Max gradient value: 0.009448257026704458
# Gradient shape: (32, 10)
# Max gradient value: 0.0014882916711672664
# Gradient shape: (1, 10)
# Max gradient value: 0.002684800782034679
# Gradient shape: (784, 32)
# Max gradient value: 0.0031817877124616103
# Gradient shape: (1, 32)
# Max gradient value: 0.0063209475873773876
# Gradient shape: (32, 10)
# Max gradient value: 0.0015710919710017702
# Gradient shape: (1, 10)
# Max gradient value: 0.00267881137361939
# Gradient shape: (784, 32)
# Max gradient value: 0.0025861983117530405
# Gradient shape: (1, 32)
# Max gradient value: 0.005275448115681591
# Gradient shape: (32, 10)
# Max gradient value: 0.0015854395745273475
# Gradient shape: (1, 10)
# Max gradient value: 0.0027448976681100426
# Gradient shape: (784, 32)
# Max gradient value: 0.0023785038364992402
# Gradient shape: (1, 32)
# Max gradient value: 0.005759928929474452
# Gradient shape: (32, 10)
# Max gradient value: 0.0015992612348733138
# Gradient shape: (1, 10)
# Max gradient value: 0.0028450675369680804
# Gradient shape: (784, 32)
# Max gradient value: 0.002647297364656975
# Gradient shape: (1, 32)
# Max gradient value: 0.009570985957136326
# Gradient shape: (32, 10)
# Max gradient value: 0.002136832045543098
# Gradient shape: (1, 10)
# Max gradient value: 0.00276441325670904
# Gradient shape: (784, 32)
# Max gradient value: 0.002355560969954825
# Gradient shape: (1, 32)
# Max gradient value: 0.008589183156975171
# Gradient shape: (32, 10)
# Max gradient value: 0.00181640018138426
# Gradient shape: (1, 10)
# Max gradient value: 0.003329352490794169
# Gradient shape: (784, 32)
# Max gradient value: 0.0029208240356870642
# Gradient shape: (1, 32)
# Max gradient value: 0.009931469807404392
# Gradient shape: (32, 10)
# Max gradient value: 0.0015104077571523994
# Gradient shape: (1, 10)
# Max gradient value: 0.0032892934895279165
# Gradient shape: (784, 32)
# Max gradient value: 0.0028278341242709494
# Gradient shape: (1, 32)
# Max gradient value: 0.008435372893891313
# Gradient shape: (32, 10)
# Max gradient value: 0.0017369657937313543
# Gradient shape: (1, 10)
# Max gradient value: 0.0033634293619546375
# Gradient shape: (784, 32)
# Max gradient value: 0.0026122198201238337
# Gradient shape: (1, 32)
# Max gradient value: 0.008180015188556572
# Gradient shape: (32, 10)
# Max gradient value: 0.0014494253699463761
# Gradient shape: (1, 10)
# Max gradient value: 0.003077545186119548
# Gradient shape: (784, 32)
# Max gradient value: 0.002166014820838877
# Gradient shape: (1, 32)
# Max gradient value: 0.005931651554869681
# Gradient shape: (32, 10)
# Max gradient value: 0.0012187678072470105
# Gradient shape: (1, 10)
# Max gradient value: 0.002566670612964934
# Gradient shape: (784, 32)
# Max gradient value: 0.002247084411280224
# Gradient shape: (1, 32)
# Max gradient value: 0.0051638555846064945
# Gradient shape: (32, 10)
# Max gradient value: 0.0021015586235208347
# Gradient shape: (1, 10)
# Max gradient value: 0.002800597810973021
# Gradient shape: (784, 32)
# Max gradient value: 0.0026629874667251524
# Gradient shape: (1, 32)
# Max gradient value: 0.004616828454654629
# Gradient shape: (32, 10)
# Max gradient value: 0.0021479798109277515
# Gradient shape: (1, 10)
# Max gradient value: 0.00425702057354482
# Gradient shape: (784, 32)
# Max gradient value: 0.004697033489477294
# Gradient shape: (1, 32)
# Max gradient value: 0.005886529309043655
# Gradient shape: (32, 10)
# Max gradient value: 0.0021691174143235108
# Gradient shape: (1, 10)
# Max gradient value: 0.004011485946920542
# Gradient shape: (784, 32)
# Max gradient value: 0.004340800431812594
# Gradient shape: (1, 32)
# Max gradient value: 0.007249799785030676
# Gradient shape: (32, 10)
# Max gradient value: 0.002151140994637777
# Gradient shape: (1, 10)
# Max gradient value: 0.0037263024408517352
# Gradient shape: (784, 32)
# Max gradient value: 0.0036089053203571006
# Gradient shape: (1, 32)
# Max gradient value: 0.0064746327772903815
# Gradient shape: (32, 10)
# Max gradient value: 0.0015666707266808928
# Gradient shape: (1, 10)
# Max gradient value: 0.003501592184098119
# Gradient shape: (784, 32)
# Max gradient value: 0.0029220345450907477
# Gradient shape: (1, 32)
# Max gradient value: 0.004663617838332374
# Gradient shape: (32, 10)
# Max gradient value: 0.0016032145510247787
# Gradient shape: (1, 10)
# Max gradient value: 0.002901917704972641
# Gradient shape: (784, 32)
# Max gradient value: 0.001799377083532072
# Gradient shape: (1, 32)
# Max gradient value: 0.005653168074161024
# Gradient shape: (32, 10)
# Max gradient value: 0.0008750148419926709
# Gradient shape: (1, 10)
# Max gradient value: 0.0033827140312632795
# Gradient shape: (784, 32)
# Max gradient value: 0.003165573872768922
# Gradient shape: (1, 32)
# Max gradient value: 0.00701167639252196
# Gradient shape: (32, 10)
# Max gradient value: 0.0014445670475608371
# Gradient shape: (1, 10)
# Max gradient value: 0.0032686818226414257
# Gradient shape: (784, 32)
# Max gradient value: 0.0029600164618337446
# Gradient shape: (1, 32)
# Max gradient value: 0.006735097086897308
# Gradient shape: (32, 10)
# Max gradient value: 0.0018122167113271107
# Gradient shape: (1, 10)
# Max gradient value: 0.0037264057131048264
# Gradient shape: (784, 32)
# Max gradient value: 0.004093297304336967
# Gradient shape: (1, 32)
# Max gradient value: 0.00680598719026835
# Gradient shape: (32, 10)
# Max gradient value: 0.0013256488897814226
# Gradient shape: (1, 10)
# Max gradient value: 0.004106143897811401
# Gradient shape: (784, 32)
# Max gradient value: 0.004718552171015716
# Gradient shape: (1, 32)
# Max gradient value: 0.009341396955938316
# Gradient shape: (32, 10)
# Max gradient value: 0.002024974440171745
# Gradient shape: (1, 10)
# Max gradient value: 0.00327765103401406
# Gradient shape: (784, 32)
# Max gradient value: 0.002973625436759041
# Gradient shape: (1, 32)
# Max gradient value: 0.007260173650734128
# Gradient shape: (32, 10)
# Max gradient value: 0.0009758596379444804
# Gradient shape: (1, 10)
# Max gradient value: 0.00249646838396982
# Gradient shape: (784, 32)
# Max gradient value: 0.0021602286422244496
# Gradient shape: (1, 32)
# Max gradient value: 0.005582402539053099
# Gradient shape: (32, 10)
# Max gradient value: 0.0009288325720657497
# Gradient shape: (1, 10)
# Max gradient value: 0.002613936890046092
# Gradient shape: (784, 32)
# Max gradient value: 0.002524187189789338
# Gradient shape: (1, 32)
# Max gradient value: 0.008651631979228637
# Gradient shape: (32, 10)
# Max gradient value: 0.0017200932324258327
# Gradient shape: (1, 10)
# Max gradient value: 0.0025276908807255515
# Gradient shape: (784, 32)
# Max gradient value: 0.0034545316054246196
# Gradient shape: (1, 32)
# Max gradient value: 0.008843852104440726
# Gradient shape: (32, 10)
# Max gradient value: 0.0019788666111403555
# Gradient shape: (1, 10)
# Max gradient value: 0.0023860807993012923
# Gradient shape: (784, 32)
# Max gradient value: 0.0035364860463183764
# Gradient shape: (1, 32)
# Max gradient value: 0.008120341167392598
# Gradient shape: (32, 10)
# Max gradient value: 0.001762128446404342
# Gradient shape: (1, 10)
# Max gradient value: 0.0022896803617683146
# Gradient shape: (784, 32)
# Max gradient value: 0.0026851445335700566
# Gradient shape: (1, 32)
# Max gradient value: 0.007919832845553119
# Gradient shape: (32, 10)
# Max gradient value: 0.0019713795912192976
# Gradient shape: (1, 10)
# Max gradient value: 0.0021407442900458367
# Gradient shape: (784, 32)
# Max gradient value: 0.0023150240595965514
# Gradient shape: (1, 32)
# Max gradient value: 0.007420579659123995
# Gradient shape: (32, 10)
# Max gradient value: 0.0017823140336275676
# Gradient shape: (1, 10)
# Max gradient value: 0.002446747137757808
# Gradient shape: (784, 32)
# Max gradient value: 0.00341925362622238
# Gradient shape: (1, 32)
# Max gradient value: 0.006890758877407037
# Gradient shape: (32, 10)
# Max gradient value: 0.0017633022157315997
# Gradient shape: (1, 10)
# Max gradient value: 0.0026567859177809195
# Gradient shape: (784, 32)
# Max gradient value: 0.0032140542171375367
# Gradient shape: (1, 32)
# Max gradient value: 0.005817683291458948
# Gradient shape: (32, 10)
# Max gradient value: 0.0013476386864488352
# Gradient shape: (1, 10)
# Max gradient value: 0.0022097987923151968
# Gradient shape: (784, 32)
# Max gradient value: 0.002366500311538649
# Gradient shape: (1, 32)
# Max gradient value: 0.005302650104457313
# Gradient shape: (32, 10)
# Max gradient value: 0.000959622413658175
# Gradient shape: (1, 10)
# Max gradient value: 0.0020445726214767795
# Gradient shape: (784, 32)
# Max gradient value: 0.0017112481198221297
# Gradient shape: (1, 32)
# Max gradient value: 0.00485331381752333
# Gradient shape: (32, 10)
# Max gradient value: 0.0006894671641924524
# Gradient shape: (1, 10)
# Max gradient value: 0.0026903876502124852
# Gradient shape: (784, 32)
# Max gradient value: 0.0025388358714427666
# Gradient shape: (1, 32)
# Max gradient value: 0.0059228160489839836
# Gradient shape: (32, 10)
# Max gradient value: 0.0008278656586072923
# Gradient shape: (1, 10)
# Max gradient value: 0.0023974669935375387
# Gradient shape: (784, 32)
# Max gradient value: 0.0018221532685355377
# Gradient shape: (1, 32)
# Max gradient value: 0.006349777122765663
# Gradient shape: (32, 10)
# Max gradient value: 0.0008693376581683846
# Gradient shape: (1, 10)
# Max gradient value: 0.002159783576628039
# Gradient shape: (784, 32)
# Max gradient value: 0.0015796232838855661
# Gradient shape: (1, 32)
# Max gradient value: 0.006494344117594298
# Gradient shape: (32, 10)
# Max gradient value: 0.0009060885608158923
# Gradient shape: (1, 10)
# Max gradient value: 0.0021217973834764515
# Gradient shape: (784, 32)
# Max gradient value: 0.0020816135459775327
# Gradient shape: (1, 32)
# Max gradient value: 0.004697006578534378
# Gradient shape: (32, 10)
# Max gradient value: 0.0011210010849891838
# Gradient shape: (1, 10)
# Max gradient value: 0.0031857493183914823
# Gradient shape: (784, 32)
# Max gradient value: 0.003307539196415827
# Gradient shape: (1, 32)
# Max gradient value: 0.006638802483114486
# Gradient shape: (32, 10)
# Max gradient value: 0.001312914480406547
# Gradient shape: (1, 10)
# Max gradient value: 0.002977196081996759
# Gradient shape: (784, 32)
# Max gradient value: 0.0031826345837280287
# Gradient shape: (1, 32)
# Max gradient value: 0.006790615156957681
# Gradient shape: (32, 10)
# Max gradient value: 0.0013748503603749635
# Gradient shape: (1, 10)
# Max gradient value: 0.002710816973113803
# Gradient shape: (784, 32)
# Max gradient value: 0.002229657229158402
# Gradient shape: (1, 32)
# Max gradient value: 0.0061956080334777995
# Gradient shape: (32, 10)
# Max gradient value: 0.0016098084897507936
# Gradient shape: (1, 10)
# Max gradient value: 0.002334033866244583
# Gradient shape: (784, 32)
# Max gradient value: 0.0021630091082737272
# Gradient shape: (1, 32)
# Max gradient value: 0.005327997905932124
# Gradient shape: (32, 10)
# Max gradient value: 0.0015533753727885336
# Gradient shape: (1, 10)
# Max gradient value: 0.0023437105560014347
# Gradient shape: (784, 32)
# Max gradient value: 0.0019984179046747845
# Gradient shape: (1, 32)
# Max gradient value: 0.005605781471651311
# Gradient shape: (32, 10)
# Max gradient value: 0.0014895030904134236
# Gradient shape: (1, 10)
# Max gradient value: 0.002091592166413118
# Gradient shape: (784, 32)
# Max gradient value: 0.0021762129494622045
# Gradient shape: (1, 32)
# Max gradient value: 0.005164316251190708
# Gradient shape: (32, 10)
# Max gradient value: 0.0011937460181374922
# Gradient shape: (1, 10)
# Max gradient value: 0.0021623514770912977
# Gradient shape: (784, 32)
# Max gradient value: 0.0022561840991479785
# Gradient shape: (1, 32)
# Max gradient value: 0.004683053709835733
# Gradient shape: (32, 10)
# Max gradient value: 0.0012313127298728558
# Gradient shape: (1, 10)
# Max gradient value: 0.0029598110583783413
# Gradient shape: (784, 32)
# Max gradient value: 0.0030701156107355706
# Gradient shape: (1, 32)
# Max gradient value: 0.004257703071922152
# Gradient shape: (32, 10)
# Max gradient value: 0.0012668058036581424
# Gradient shape: (1, 10)
# Max gradient value: 0.002707131266181381
# Gradient shape: (784, 32)
# Max gradient value: 0.002864847006018828
# Gradient shape: (1, 32)
# Max gradient value: 0.004878792978805899
# Gradient shape: (32, 10)
# Max gradient value: 0.0014781010597289322
# Gradient shape: (1, 10)
# Max gradient value: 0.002507873839448209
# Gradient shape: (784, 32)
# Max gradient value: 0.0027626578828196025
# Gradient shape: (1, 32)
# Max gradient value: 0.005091960766229266
# Gradient shape: (32, 10)
# Max gradient value: 0.0014762476955385137
# Gradient shape: (1, 10)
# Max gradient value: 0.0026202029013633744
# Gradient shape: (784, 32)
# Max gradient value: 0.0025321000345062926
# Gradient shape: (1, 32)
# Max gradient value: 0.006065755112988531
# Gradient shape: (32, 10)
# Max gradient value: 0.0012633997085863885
# Gradient shape: (1, 10)
# Max gradient value: 0.0024191429242191287
# Gradient shape: (784, 32)
# Max gradient value: 0.002318063404579574
# Gradient shape: (1, 32)
# Max gradient value: 0.006293185504033
# Gradient shape: (32, 10)
# Max gradient value: 0.0009125567618591152
# Gradient shape: (1, 10)
# Max gradient value: 0.0022521725879595025
# Gradient shape: (784, 32)
# Max gradient value: 0.002399390439069269
# Gradient shape: (1, 32)
# Max gradient value: 0.005869008200897713
# Gradient shape: (32, 10)
# Max gradient value: 0.0004578798912139364
# Gradient shape: (1, 10)
# Max gradient value: 0.0024550616109610705
# Gradient shape: (784, 32)
# Max gradient value: 0.0026938967708599734
# Gradient shape: (1, 32)
# Max gradient value: 0.006607999646804262
# Gradient shape: (32, 10)
# Max gradient value: 0.0010387041625257985
# Gradient shape: (1, 10)
# Max gradient value: 0.0023867351516332906
# Gradient shape: (784, 32)
# Max gradient value: 0.0029413410849397654
# Gradient shape: (1, 32)
# Max gradient value: 0.006229251723675116
# Gradient shape: (32, 10)
# Max gradient value: 0.0014475684997377054
# Gradient shape: (1, 10)
# Max gradient value: 0.0025257687160832308
# Gradient shape: (784, 32)
# Max gradient value: 0.00203772797799732
# Gradient shape: (1, 32)
# Max gradient value: 0.007841235828000892
# Gradient shape: (32, 10)
# Max gradient value: 0.0015318466925322775
# Gradient shape: (1, 10)
# Max gradient value: 0.0031932372872811813
# Gradient shape: (784, 32)
# Max gradient value: 0.0029455631237704488
# Gradient shape: (1, 32)
# Max gradient value: 0.010674574179661025
# Gradient shape: (32, 10)
# Max gradient value: 0.001441689034019439
# Gradient shape: (1, 10)
# Max gradient value: 0.0030475778946145752
# Gradient shape: (784, 32)
# Max gradient value: 0.002847521839515642
# Gradient shape: (1, 32)
# Max gradient value: 0.009284483693638079
# Gradient shape: (32, 10)
# Max gradient value: 0.0012313515783482082
# Gradient shape: (1, 10)
# Max gradient value: 0.0022169676192892907
# Gradient shape: (784, 32)
# Max gradient value: 0.0020267113032609026
# Gradient shape: (1, 32)
# Max gradient value: 0.006617793558578316
# Gradient shape: (32, 10)
# Max gradient value: 0.001280464341811405
# Gradient shape: (1, 10)
# Max gradient value: 0.0026792340030279364
# Gradient shape: (784, 32)
# Max gradient value: 0.0015422251320920122
# Gradient shape: (1, 32)
# Max gradient value: 0.008149060443323957
# Gradient shape: (32, 10)
# Max gradient value: 0.0014514892311958108
# Gradient shape: (1, 10)
# Max gradient value: 0.003155333610869202
# Gradient shape: (784, 32)
# Max gradient value: 0.0023943407164935884
# Gradient shape: (1, 32)
# Max gradient value: 0.008469336734394383
# Gradient shape: (32, 10)
# Max gradient value: 0.0013714046019526192
# Gradient shape: (1, 10)
# Max gradient value: 0.002820739052467967
# Gradient shape: (784, 32)
# Max gradient value: 0.0022230788459073644
# Gradient shape: (1, 32)
# Max gradient value: 0.008098195425200894
# Gradient shape: (32, 10)
# Max gradient value: 0.0013309865044114039
# Gradient shape: (1, 10)
# Max gradient value: 0.001966843341873416
# Gradient shape: (784, 32)
# Max gradient value: 0.0014912203583076424
# Gradient shape: (1, 32)
# Max gradient value: 0.006542262056226951
# Gradient shape: (32, 10)
# Max gradient value: 0.0009352491655010267
# Gradient shape: (1, 10)
# Max gradient value: 0.001991013006131258
# Gradient shape: (784, 32)
# Max gradient value: 0.0011307801238455138
# Gradient shape: (1, 32)
# Max gradient value: 0.006293092042023421
# Gradient shape: (32, 10)
# Max gradient value: 0.000794070777657664
# Gradient shape: (1, 10)
# Max gradient value: 0.002189903377106071
# Gradient shape: (784, 32)
# Max gradient value: 0.0013230040315103146
# Gradient shape: (1, 32)
# Max gradient value: 0.0055064152269368285
# Gradient shape: (32, 10)
# Max gradient value: 0.0010035303898610678
# Gradient shape: (1, 10)
# Max gradient value: 0.002522906206631736
# Gradient shape: (784, 32)
# Max gradient value: 0.0015348993958231515
# Gradient shape: (1, 32)
# Max gradient value: 0.0051431110099797615
# Gradient shape: (32, 10)
# Max gradient value: 0.0011170470504513537
# Gradient shape: (1, 10)
# Max gradient value: 0.0029303732705487097
# Gradient shape: (784, 32)
# Max gradient value: 0.003328466424533507
# Gradient shape: (1, 32)
# Max gradient value: 0.006354799421427252
# Gradient shape: (32, 10)
# Max gradient value: 0.001609524688281376
# Gradient shape: (1, 10)
# Max gradient value: 0.002902177978392961
# Gradient shape: (784, 32)
# Max gradient value: 0.00330847791394728
# Gradient shape: (1, 32)
# Max gradient value: 0.005826310436875671
# Gradient shape: (32, 10)
# Max gradient value: 0.0011949084602044838
# Gradient shape: (1, 10)
# Max gradient value: 0.00266395754860528
# Gradient shape: (784, 32)
# Max gradient value: 0.0031303395026599117
# Gradient shape: (1, 32)
# Max gradient value: 0.005759724235639281
# Gradient shape: (32, 10)
# Max gradient value: 0.001330090501642409
# Gradient shape: (1, 10)
# Max gradient value: 0.002800036787858458
# Gradient shape: (784, 32)
# Max gradient value: 0.0032818134563848333
# Gradient shape: (1, 32)
# Max gradient value: 0.0070398384884610594
# Gradient shape: (32, 10)
# Max gradient value: 0.0019359886561678514
# Gradient shape: (1, 10)
# Max gradient value: 0.003191909762814204
# Gradient shape: (784, 32)
# Max gradient value: 0.0026696553903655636
# Gradient shape: (1, 32)
# Max gradient value: 0.006957616653941708
# Gradient shape: (32, 10)
# Max gradient value: 0.002418109681531234
# Gradient shape: (1, 10)
# Max gradient value: 0.002651451081764203
# Gradient shape: (784, 32)
# Max gradient value: 0.0023872779877968232
# Gradient shape: (1, 32)
# Max gradient value: 0.00923143883966426
# Gradient shape: (32, 10)
# Max gradient value: 0.002762235702468355
# Gradient shape: (1, 10)
# Max gradient value: 0.0027236711926853824
# Gradient shape: (784, 32)
# Max gradient value: 0.001979850909309708
# Gradient shape: (1, 32)
# Max gradient value: 0.008279277529906218
# Gradient shape: (32, 10)
# Max gradient value: 0.0014220829390786441
# Gradient shape: (1, 10)
# Max gradient value: 0.003330210856634248
# Gradient shape: (784, 32)
# Max gradient value: 0.0020173253788457507
# Gradient shape: (1, 32)
# Max gradient value: 0.00773225299803614
# Gradient shape: (32, 10)
# Max gradient value: 0.0018423659449498793
# Gradient shape: (1, 10)
# Max gradient value: 0.004628271959560336
# ...
# Max gradient value: 0.005039349541766313
# Gradient shape: (784, 32)
# Max gradient value: 0.004670786676986143
# Gradient shape: (1, 32)
# Max gradient value: 0.01084313118635833
# Gradient shape: (32, 10)
# Max gradient value: 0.0016494899372092953
# Gradient shape: (1, 10)
# Max gradient value: 0.0047258343221729645
# Gradient shape: (784, 32)
# Max gradient value: 0.004426860303841291
# Gradient shape: (1, 32)
# Max gradient value: 0.009865067685518206
# Gradient shape: (32, 10)
# Max gradient value: 0.0017919850603072404
# Gradient shape: (1, 10)
# Max gradient value: 0.004290053642088097
# Gradient shape: (784, 32)
# Max gradient value: 0.004201971791834781
# Gradient shape: (1, 32)
# Max gradient value: 0.009691513969735745
# Gradient shape: (32, 10)
# Max gradient value: 0.001397862054080631
# Gradient shape: (1, 10)
# Max gradient value: 0.003918384426417327
# Gradient shape: (784, 32)
# Max gradient value: 0.0035220965471971523
# Gradient shape: (1, 32)
# Max gradient value: 0.008557647053701453
# Gradient shape: (32, 10)
# Max gradient value: 0.0014964829646306051
# Gradient shape: (1, 10)
# Max gradient value: 0.003689913888888512
# Gradient shape: (784, 32)
# Max gradient value: 0.003339865475351283
# Gradient shape: (1, 32)
# Max gradient value: 0.0065329747498540595
# Gradient shape: (32, 10)
# Max gradient value: 0.0013466437938657173
# Gradient shape: (1, 10)
# Max gradient value: 0.0037267609939311205
# Gradient shape: (784, 32)
# Max gradient value: 0.0037057954665275774
# Gradient shape: (1, 32)
# Max gradient value: 0.008194696626593828
# Gradient shape: (32, 10)
# Max gradient value: 0.002189517345504047
# Gradient shape: (1, 10)
# Max gradient value: 0.004733171398368222
# Gradient shape: (784, 32)
# Max gradient value: 0.004284713749222338
# Gradient shape: (1, 32)
# Max gradient value: 0.0062092207238980245
# Gradient shape: (32, 10)
# Max gradient value: 0.0017765961951592558
# Gradient shape: (1, 10)
# Max gradient value: 0.004303313976515545
# Gradient shape: (784, 32)
# Max gradient value: 0.003819773021842162
# Gradient shape: (1, 32)
# Max gradient value: 0.006598868601715506
# Gradient shape: (32, 10)
# Max gradient value: 0.0017472894509914763
# Gradient shape: (1, 10)
# Max gradient value: 0.004241092732977175
# Gradient shape: (784, 32)
# Max gradient value: 0.003669749798289248
# Gradient shape: (1, 32)
# Max gradient value: 0.008311534846792817
# Gradient shape: (32, 10)
# Max gradient value: 0.00234715319243447
# Gradient shape: (1, 10)
# Max gradient value: 0.003365637515079818
# Gradient shape: (784, 32)
# Max gradient value: 0.0033666444429316265
# Gradient shape: (1, 32)
# Max gradient value: 0.008698154533908067
# Gradient shape: (32, 10)
# Max gradient value: 0.0022503979299423617
# Gradient shape: (1, 10)
# Max gradient value: 0.0032371809248316324
# Gradient shape: (784, 32)
# Max gradient value: 0.0037049302868693416
# Gradient shape: (1, 32)
# Max gradient value: 0.015165000508699901
# Gradient shape: (32, 10)
# Max gradient value: 0.003315567996022
# Gradient shape: (1, 10)
# Max gradient value: 0.0044692817492374875
# Gradient shape: (784, 32)
# Max gradient value: 0.006321943583175732
# Gradient shape: (1, 32)
# Max gradient value: 0.018377311626118362
# Gradient shape: (32, 10)
# Max gradient value: 0.004131634265543693
# Gradient shape: (1, 10)
# Max gradient value: 0.0038863851248310374
# Gradient shape: (784, 32)
# Max gradient value: 0.005679819827630712
# Gradient shape: (1, 32)
# Max gradient value: 0.015929697166046274
# Gradient shape: (32, 10)
# Max gradient value: 0.0036262202094368466
# Gradient shape: (1, 10)
# Max gradient value: 0.0036836414967225703
# Gradient shape: (784, 32)
# Max gradient value: 0.005431536446125274
# Gradient shape: (1, 32)
# Max gradient value: 0.01468787809913874
# Gradient shape: (32, 10)
# Max gradient value: 0.00341054000087398
# Gradient shape: (1, 10)
# Max gradient value: 0.0037337398295028404
# Gradient shape: (784, 32)
# Max gradient value: 0.005296711633255029
# Gradient shape: (1, 32)
# Max gradient value: 0.011846903333433722
# Gradient shape: (32, 10)
# Max gradient value: 0.0023524536961681665
# Gradient shape: (1, 10)
# Max gradient value: 0.0030642733586877034
# Gradient shape: (784, 32)
# Max gradient value: 0.00438087033308978
# Gradient shape: (1, 32)
# Max gradient value: 0.00996097071865486
# Gradient shape: (32, 10)
# Max gradient value: 0.0021314792272152934
# Gradient shape: (1, 10)
# Max gradient value: 0.0030617253546887557
# Gradient shape: (784, 32)
# Max gradient value: 0.003160461310911885
# Gradient shape: (1, 32)
# Max gradient value: 0.008565376233682125
# Gradient shape: (32, 10)
# Max gradient value: 0.0015315323596089537
# Gradient shape: (1, 10)
# Max gradient value: 0.0033317640990545533
# Gradient shape: (784, 32)
# Max gradient value: 0.002946783725535693
# Gradient shape: (1, 32)
# Max gradient value: 0.006189054811782148
# Gradient shape: (32, 10)
# Max gradient value: 0.0020279651683976444
# Gradient shape: (1, 10)
# Max gradient value: 0.00392881508525054
# Gradient shape: (784, 32)
# Max gradient value: 0.0029682123538864623
# Gradient shape: (1, 32)
# Max gradient value: 0.0061707162854891555
# Gradient shape: (32, 10)
# Max gradient value: 0.0021546651426467543
# Gradient shape: (1, 10)
# Max gradient value: 0.003193622825910202
# Gradient shape: (784, 32)
# Max gradient value: 0.002795752240406346
# Gradient shape: (1, 32)
# Max gradient value: 0.005960118215331818
# Gradient shape: (32, 10)
# Max gradient value: 0.002206015669022482
# Gradient shape: (1, 10)
# Max gradient value: 0.0036152672597166667
# Gradient shape: (784, 32)
# Max gradient value: 0.003651072868989946
# Gradient shape: (1, 32)
# Max gradient value: 0.007604415802531322
# Gradient shape: (32, 10)
# Max gradient value: 0.00214009711885961
# Gradient shape: (1, 10)
# Max gradient value: 0.0032607190478103638
# Gradient shape: (784, 32)
# Max gradient value: 0.003247491165881855
# Gradient shape: (1, 32)
# Max gradient value: 0.007826460882198039
# Gradient shape: (32, 10)
# Max gradient value: 0.0017918266400906429
# Gradient shape: (1, 10)
# Max gradient value: 0.0035516628757816604
# Gradient shape: (784, 32)
# Max gradient value: 0.003292165069452197
# Gradient shape: (1, 32)
# Max gradient value: 0.007536919396325939
# Gradient shape: (32, 10)
# Max gradient value: 0.0013570019923719073
# Gradient shape: (1, 10)
# Max gradient value: 0.003145798682225028
# Gradient shape: (784, 32)
# Max gradient value: 0.0030678294218637187
# Gradient shape: (1, 32)
# Max gradient value: 0.007993543040325233
# Gradient shape: (32, 10)
# Max gradient value: 0.001600250006726779
# Gradient shape: (1, 10)
# Max gradient value: 0.0035272286896109984
# Gradient shape: (784, 32)
# Max gradient value: 0.0037803522015678235
# Gradient shape: (1, 32)
# Max gradient value: 0.011187810131588679
# Gradient shape: (32, 10)
# Max gradient value: 0.0021420852389878063
# Gradient shape: (1, 10)
# Max gradient value: 0.0033243843696203084
# Gradient shape: (784, 32)
# Max gradient value: 0.0036987192715860324
# Gradient shape: (1, 32)
# Max gradient value: 0.011151920417166039
# Gradient shape: (32, 10)
# Max gradient value: 0.002127713874960085
# Gradient shape: (1, 10)
# Max gradient value: 0.003008882704625349
# Gradient shape: (784, 32)
# Max gradient value: 0.003494140238843845
# Gradient shape: (1, 32)
# Max gradient value: 0.010511439434612226
# Gradient shape: (32, 10)
# Max gradient value: 0.002115228534947146
# Gradient shape: (1, 10)
# Max gradient value: 0.002726060459019377
# Gradient shape: (784, 32)
# Max gradient value: 0.0032187449238126496
# Gradient shape: (1, 32)
# Max gradient value: 0.00897565628177854
# Gradient shape: (32, 10)
# Max gradient value: 0.0014913577989731088
# Gradient shape: (1, 10)
# Max gradient value: 0.0027077196675683915
# Gradient shape: (784, 32)
# Max gradient value: 0.0029677079821306637
# Gradient shape: (1, 32)
# Max gradient value: 0.008117895389866387
# Gradient shape: (32, 10)
# Max gradient value: 0.0009893900917495183
# Gradient shape: (1, 10)
# Max gradient value: 0.002360930170780386
# Gradient shape: (784, 32)
# Max gradient value: 0.0025441058174641203
# Gradient shape: (1, 32)
# Max gradient value: 0.007034110182659393
# Gradient shape: (32, 10)
# Max gradient value: 0.0009576778063684217
# Gradient shape: (1, 10)
# Max gradient value: 0.0025273411612142162
# Gradient shape: (784, 32)
# Max gradient value: 0.002832457347844983
# Gradient shape: (1, 32)
# Max gradient value: 0.006201263873385633
# Gradient shape: (32, 10)
# Max gradient value: 0.001168598752350771
# Gradient shape: (1, 10)
# Max gradient value: 0.0025002995393785202
# Gradient shape: (784, 32)
# Max gradient value: 0.002123968655001673
# Gradient shape: (1, 32)
# Max gradient value: 0.007766512083980491
# Gradient shape: (32, 10)
# Max gradient value: 0.001394542989588105
# Gradient shape: (1, 10)
# Max gradient value: 0.002674545111749918
# Gradient shape: (784, 32)
# Max gradient value: 0.002352398801138854
# Gradient shape: (1, 32)
# Max gradient value: 0.008161147878623485
# Gradient shape: (32, 10)
# Max gradient value: 0.0016209091958568848
# Gradient shape: (1, 10)
# Max gradient value: 0.002411896962324554
# Gradient shape: (784, 32)
# Max gradient value: 0.0018433149659541899
# Gradient shape: (1, 32)
# Max gradient value: 0.006846591583300993
# Gradient shape: (32, 10)
# Max gradient value: 0.001425512385196947
# Gradient shape: (1, 10)
# Max gradient value: 0.0025365702399026825
# Gradient shape: (784, 32)
# Max gradient value: 0.0023768052069707583
# Gradient shape: (1, 32)
# Max gradient value: 0.006283471289250683
# Gradient shape: (32, 10)
# Max gradient value: 0.0009453800431577944
# Gradient shape: (1, 10)
# Max gradient value: 0.0025919982910650487
# Gradient shape: (784, 32)
# Max gradient value: 0.0021712527503062575
# Gradient shape: (1, 32)
# Max gradient value: 0.005397613300563885
# Gradient shape: (32, 10)
# Max gradient value: 0.0007190257868311583
# Gradient shape: (1, 10)
# Max gradient value: 0.004669067382641064
# Gradient shape: (784, 32)
# Max gradient value: 0.004331126522087945
# Gradient shape: (1, 32)
# Max gradient value: 0.006050243835047874
# Gradient shape: (32, 10)
# Max gradient value: 0.0008745069184902409
# Gradient shape: (1, 10)
# Max gradient value: 0.004269903632411365
# Gradient shape: (784, 32)
# Max gradient value: 0.0042964510981049475
# Gradient shape: (1, 32)
# Max gradient value: 0.006611718398238727
# Gradient shape: (32, 10)
# Max gradient value: 0.0009915716367746668
# Gradient shape: (1, 10)
# Max gradient value: 0.004099814161070035
# Gradient shape: (784, 32)
# Max gradient value: 0.003975929144267352
# Gradient shape: (1, 32)
# Max gradient value: 0.006146080967027759
# Gradient shape: (32, 10)
# Max gradient value: 0.0015612691914345814
# Gradient shape: (1, 10)
# Max gradient value: 0.0038248813957952616
# Gradient shape: (784, 32)
# Max gradient value: 0.004003419420531378
# Gradient shape: (1, 32)
# Max gradient value: 0.005241929508322861
# Gradient shape: (32, 10)
# Max gradient value: 0.0007338731891922397
# Gradient shape: (1, 10)
# Max gradient value: 0.003927214038634815
# Gradient shape: (784, 32)
# Max gradient value: 0.0038724997864326613
# Gradient shape: (1, 32)
# Max gradient value: 0.00519185490204299
# Gradient shape: (32, 10)
# Max gradient value: 0.0009775901578618533
# Gradient shape: (1, 10)
# Max gradient value: 0.003740268461940249
# Gradient shape: (784, 32)
# Max gradient value: 0.0033323240597306018
# Gradient shape: (1, 32)
# Max gradient value: 0.012261640600900788
# Gradient shape: (32, 10)
# Max gradient value: 0.001912943119442082
# Gradient shape: (1, 10)
# Max gradient value: 0.0038658575977346095
# Gradient shape: (784, 32)
# Max gradient value: 0.0040466615177624805
# Gradient shape: (1, 32)
# Max gradient value: 0.011355901358580897
# Gradient shape: (32, 10)
# Max gradient value: 0.001923854536542086
# Gradient shape: (1, 10)
# Max gradient value: 0.003942922627111507
# Gradient shape: (784, 32)
# Max gradient value: 0.004923130646920333
# Gradient shape: (1, 32)
# Max gradient value: 0.011841939509100763
# Gradient shape: (32, 10)
# Max gradient value: 0.002563592529809037
# Gradient shape: (1, 10)
# Max gradient value: 0.0038294792914768047
# Gradient shape: (784, 32)
# Max gradient value: 0.003972994687256886
# Gradient shape: (1, 32)
# Max gradient value: 0.011098334948981242
# Gradient shape: (32, 10)
# Max gradient value: 0.0028303259940812993
# Gradient shape: (1, 10)
# Max gradient value: 0.0035364247800709846
# Gradient shape: (784, 32)
# Max gradient value: 0.0031693801945676826
# Gradient shape: (1, 32)
# Max gradient value: 0.006027233631871675
# Gradient shape: (32, 10)
# Max gradient value: 0.0012697676150909506
# Gradient shape: (1, 10)
# Max gradient value: 0.003346901795118717
# Gradient shape: (784, 32)
# Max gradient value: 0.003538725263639625
# Gradient shape: (1, 32)
# Max gradient value: 0.005972092104679324
# Gradient shape: (32, 10)
# Max gradient value: 0.0013086281538633223
# Gradient shape: (1, 10)
# Max gradient value: 0.003038269373044107
# Gradient shape: (784, 32)
# Max gradient value: 0.0027041957991806556
# Gradient shape: (1, 32)
# Max gradient value: 0.004023130276470143
# Gradient shape: (32, 10)
# Max gradient value: 0.001205099999811144
# Gradient shape: (1, 10)
# Max gradient value: 0.003885099520155268
# Gradient shape: (784, 32)
# Max gradient value: 0.0036188051929535703
# Gradient shape: (1, 32)
# Max gradient value: 0.005832924050806246
# Gradient shape: (32, 10)
# Max gradient value: 0.0013489289942960041
# Gradient shape: (1, 10)
# Max gradient value: 0.004047080322006823
# Gradient shape: (784, 32)
# Max gradient value: 0.004687979988945766
# Gradient shape: (1, 32)
# Max gradient value: 0.006664986151933991
# Gradient shape: (32, 10)
# Max gradient value: 0.0016282365440621735
# Gradient shape: (1, 10)
# Max gradient value: 0.0038310135203889054
# Gradient shape: (784, 32)
# Max gradient value: 0.004376080938533515
# Gradient shape: (1, 32)
# Max gradient value: 0.006495301859925617
# Gradient shape: (32, 10)
# Max gradient value: 0.00132851718160111
# Gradient shape: (1, 10)
# Max gradient value: 0.0037503592604321047
# Gradient shape: (784, 32)
# Max gradient value: 0.0028273550930318593
# Gradient shape: (1, 32)
# Max gradient value: 0.011910414384814386
# Gradient shape: (32, 10)
# Max gradient value: 0.0023357312529259174
# Gradient shape: (1, 10)
# Max gradient value: 0.0031394985705310297
# Gradient shape: (784, 32)
# Max gradient value: 0.00326029311334013
# Gradient shape: (1, 32)
# Max gradient value: 0.008930531668475154
# Gradient shape: (32, 10)
# Max gradient value: 0.002021556799635029
# Gradient shape: (1, 10)
# Max gradient value: 0.0035845486650136985
# Gradient shape: (784, 32)
# Max gradient value: 0.003706998000876917
# Gradient shape: (1, 32)
# Max gradient value: 0.010304993075945363
# Gradient shape: (32, 10)
# Max gradient value: 0.00310865311526581
# Gradient shape: (1, 10)
# Max gradient value: 0.004018252913827215
# Gradient shape: (784, 32)
# Max gradient value: 0.004099529822315958
# Gradient shape: (1, 32)
# Max gradient value: 0.011102842804989207
# Gradient shape: (32, 10)
# Max gradient value: 0.003261815912803303
# Gradient shape: (1, 10)
# Max gradient value: 0.0034934481271708413
# Gradient shape: (784, 32)
# Max gradient value: 0.0037886434272321598
# Gradient shape: (1, 32)
# Max gradient value: 0.013408312899880623
# Gradient shape: (32, 10)
# Max gradient value: 0.003504030308031969
# Gradient shape: (1, 10)
# Max gradient value: 0.0037626844450366417
# Gradient shape: (784, 32)
# Max gradient value: 0.0032212486222519595
# Gradient shape: (1, 32)
# Max gradient value: 0.0143608414767215
# Gradient shape: (32, 10)
# Max gradient value: 0.003656783936116158
# Gradient shape: (1, 10)
# Max gradient value: 0.003882096877033796
# Gradient shape: (784, 32)
# Max gradient value: 0.0032931613161589464
# Gradient shape: (1, 32)
# Max gradient value: 0.012850914447028516
# Gradient shape: (32, 10)
# Max gradient value: 0.0029367600672935436
# Gradient shape: (1, 10)
# Max gradient value: 0.00351963565331678
# Gradient shape: (784, 32)
# Max gradient value: 0.001959421783998646
# Gradient shape: (1, 32)
# Max gradient value: 0.010724196199467587
# Gradient shape: (32, 10)
# Max gradient value: 0.0020792358905371944
# Gradient shape: (1, 10)
# Max gradient value: 0.0038778391885223216
# Gradient shape: (784, 32)
# Max gradient value: 0.0028398010772907392
# Gradient shape: (1, 32)
# Max gradient value: 0.011043162773184156
# Gradient shape: (32, 10)
# Max gradient value: 0.001873350164817869
# Gradient shape: (1, 10)
# Loss = 0.00046781197602030304 | Training Accuracy = 0.9761833333333333 | Val Loss = 5.0908281612753795e-05 | Val Accuracy = 0.9629

# %% [markdown]
# #### fprop a single image and showing its prediction

# %%
plt.imshow(X_val[0].reshape(28,28), cmap='gray')

# %%
# Predict Scores for each class
prediction = nn.predict_scores(X_val[0])[0]

# %%
print ("Scores")
print (prediction)
# Out:
# Scores
# [ -1.91651193  -5.74711716  -1.33109031   6.35922428  -4.79958922
#   -1.51203192 -10.02155732  17.33751905  -1.06333759   2.02192688]

# %%
np.argmax(prediction)
# Out:
# 7

# %%
predict_class = nn.predict(X_val[0])[0]
predict_class
# Out:
# 7

# %%
# Original class
y_val[0]
# Out:
# 7
