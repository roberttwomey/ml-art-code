# %% [markdown]
# ## Vanilla RNN
# Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
#
# BSD License
#
# Source: [https://gist.github.com/karpathy/d4dee566867f8291f086](https://gist.github.com/karpathy/d4dee566867f8291f086)

# %%
# !wget https://raw.githubusercontent.com/roberttwomey/ml-art-code/master/intro/script.txt
# Out:
# --2024-01-22 04:35:44--  https://raw.githubusercontent.com/roberttwomey/ml-art-code/master/intro/script.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82463 (81K) [text/plain]
# Saving to: ‘script.txt’
#
# script.txt          100%[===================>]  80.53K  --.-KB/s    in 0.01s
#
# 2024-01-22 04:35:44 (5.34 MB/s) - ‘script.txt’ saved [82463/82463]

# %%
import numpy as np

# data I/O
data = open('script.txt', 'r', encoding ='ISO-8859-1').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see

    #if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """
  sample a sequence of integers from the model
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0:
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress

  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by],
                                [dWxh, dWhh, dWhy, dbh, dby],
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 82463 characters, 95 unique.
# ----
#  	7vn|kÑ(6ÓuCO-Lqrf;G'OÒ'5Ókp¨^@ k,Y6ÑA8q)Ñ@KÑf!<FEXIKT5P@]
# 	H:BGdfHnUYWN4"N_ng4Dx9-+9MAH/w9NV.lmn#pl/BL*V6Ñu<>3ErK(3wI,1jw
# 5-@2rU#C>Ðc!IYu'15nRK?2:+sys
# HoBO"![55$4i0fe^|fWdUJNhZÑM14Z:s!vJZ$q(kXx3s|b8-
# ----
# iter 0, loss: 113.846926
# ----
#  i o  ti  ienn iaoe e ytdieatoeersetehtttooosndseogahot nt n adm
# dtr oale ainnote  ie r ct f
#  e   tawhe tmortldthryhing dndegt tdllid teo w as sai  dwr.ost.a etri pehct  rhdte KhdIdnd  ywsdeo rokHetrad
# ----
# iter 100, loss: 112.818411
# ----
#  am  r,a gnoCi
# srolle s ' atna en p
# nfstsredaictlxiu  id.enouaba.ds
# S .n g'eee.ni
#  tyy.
# etw,y k
# mneiikndudznsee li e
#   im sNs eIhe 'tim  al Il a
# frx.aIll 8fre er  e Meiauia
# vel i
# oee  t t
# asI eeat
#
# ----
# iter 200, loss: 109.871800
# ----
#  @v
# lrp@kerc
#   @
# hm@kyc@.hpmeyn@nre@aas@l@rgi0e@sgrs skebch@fap r@l .@ec it@  . .
# n@bms o
# a rau@n c po xxirahhmderr@ @  r@uygneos@m@olahaad@e stetn@eah@l@a@s e lme@ekn@r@e@.@xak@ner
#
# @g@o r@.tek dd ogs
# ----
# iter 300, loss: 107.206247
# ----
#  aYseafrYuasYit  .c' pYsolew. r r
# aorsase
# YgrsYnorourenhtssfYdmV. aumnasYlnpdsmpofmsiliya.pUesesrie  la-iqYeapigvtroht.nbpmcamuratooY-,gt-vvYi|wsessoees  h  gdn
# SYaYdpiYO.i vYtesY Ygd-doirdnus ntn sr r
# ----
# iter 400, loss: 104.490985
# ----
#   fekdd  ag fdL.s
#
# dhgwniot Aapeeelnp  tfsesces s 'os e e tediiFfoveenubrsiae iaLatelrt s ao,  swaonuefeiaseI  s nn  alote Ire asepst etryr  alme rifntoih?aioa  ota yaoyhegs aK4plemalean? utt  otutas e
# ----
# iter 500, loss: 102.112543
# ----
#  ? uy
#
#
#  habm owtotrhen veitl
#
#
#
#
# ,a5l aaufren st tlo
#  /ev cae atr s uffe
# e h.es f .
#
# n ahn  +y meoetg ycvr taied ciocn wgc men ihoipye gtdd. Iatso usf rro oo. iPolasoy  l oesnogi.
#
# ri.m cetkoaihido
# ----
# iter 600, loss: 99.302278
# ----
#  e ranurteif sor  oo^r uo'  teaieirg tinte.  fin potusayt coyrt os fof kioPtato2e ree fiobeate
# rts rerippri b twfae olyst  sl itoanh . lcop hhi ecs ob fisusheurukev y eoco5vt y fb otanuseher noterh ose
# ----
# iter 700, loss: 96.993161
# ----
#  cfama tyork.  ,s rte oyl siun. cail.  yes ps  ketv ond.anijrd chimtotewakb hour.
#
#
#
# eIau.
#  ugsenodan pon lewitocrcuspmicmcir:le, yst ltsala Np.y litndithespikigevanrtets foanewrosvi tod onicare ycomn
# ----
# iter 800, loss: 94.301963
# ----
#   ticbI  sep ate t paavhe ramife d bon suf
#
# mheios.
# ing we rzhies 0neterim le im f ytt rhatdiodiwpin ma.
# tynin manonthenl. meadt,euman mpanlons syieeIomlf onngriailetain.
#
#
#  aqwahing, sienult bileruli
# ----
# iter 900, loss: 91.652078
# ----
#  bneal,
# rbuasy
# rbatgilk cierg ae budy cate no thy mendebbect o, mrsaciif nhmt thanhml th ot iteabiv srevebem.
#
#
#
#
# Oen cid ote (he uaugee stinlo venl'g tmirc. rere ertrreb wved  iospect eut ancit aph
# ----
# iter 1000, loss: 89.328667
# ----
#  l aolymose tirr keret and iei ippythaeles ade mheitag iwe isu th retc av reac sthol tnietestmacksT
# laft cheu, ipu hiass out iint pitititiu mooclin ichiabet obe (orhaicilt ruty whhrins fror ofr of on a
# ----
# iter 1100, loss: 86.957809
# ----
#  ing mt qf and randee ticinTadl thtent he petoxd, tinede rreminisy ukioln  hing ceh of msanvhek ronentra"ene on mo, san anp usaunitepegewe an te, mad bravritf e fudhe g whe gt risy un cul thiu pseteesn
# ----
# iter 1200, loss: 84.695807
# ----
#  . wplag wil Ie al wadiamaeome c rothe phundd alin lkevscang is tonpolctctre dat nir s freugr woyl moe tsa0d.  wasejye I berfy gsio ttil To  weestedronlisil seowt,ice prind whiarsaunsesu lndkind I mof
# ----
# iter 1300, loss: 82.670574
# ----
#  hashy trat at moudics at rha.
#
# fatr  heak roruchat  otuributth posit l thaat tite kys  and Wnikmeng  iwh eag ay it lcaritl _ot cit t nallt'y + ond mta be wpantrcant pot sime fang md res cheny tho I m
# ----
# iter 1400, loss: 80.667304
# ----
#  rannle coeg yhorig
# (byan uf,
#
# pmobohuve s, end muke ¨d ko piglengr aue, s in ootiSg of crhomdp she wheu besin5 wojging tint mdatae tho ond cidcather I woang  oxhiun to.
# Ioorpit of cot kincrprd, r s
# ----
# iter 1500, loss: 78.843551
# ----
#  ler molichicasleled. wd oud poous dof llafd re.
#
# Loens sname borcave bit lomitort unoniworesticafe bid anlings deakcocliolos ans dotir sod ace ncaty m icy med.
#
# 8kinp athcrcit,
#
# os ere nousthi macert
# ----
# iter 1600, loss: 77.161111
# ----
#   bud make opdipslAs halg y duv. mheuch wos sol aller.
#
# mas sh y tanR aeun ondiklitsss
# Sber bak fme ors y) bNle I sune toe tha sitif vd nan pane  I worakat.  hhi2nan.  obuy dont briautn
# I Rurt.
#
# waat
# ----
# iter 1700, loss: 75.899321
# ----
#  lsdy tis-an torplhtactralded,ico sies anb bI pinn, in at aveas mos oic'o ion ant Is cof  pe n buirdent. bfer ink rdinacinol clat ift areshyunding. inginds to sherd nondcondbI ul wreasing sef onsesgex,
# ----
# iter 1800, loss: 74.950297
# ----
#  m.
#  mountre satt at in le t.
#
# I hiths a'nind selts al msoslith oe spa  ubelre oke ont d" ig acot fe yed.  at tdut ant toretit ans.  are a isisy the fthirst.
# tw femet yo thibld of ole sal tauc erl.e
#
#
# ----
# iter 1900, loss: 73.597143
# ----
#  ale get enemind, mo.k thags, polilf
#
# ondild azhive cinsicis eniredtas ror,icilt he resy one merntie  cing dutsiftonad#imedict inthy heing poalelan 8olkrir, iny.
#
# Pre asp uldalriuntinaf if, sgon touler
# ----
# iter 2000, loss: 72.550700
# ----
#  o.
#
# chocjuc el.
#
# ass to plat imtes atlabemamingimpgukahecyrinscendre pagtallin, tecerer nepicemersche tor m-uacl.
#
#
# minse nolation oralgey.
#
# +ricirerin ctcerrgerymoeMsineloto pange on lhep.
# htcaeeror
# ----
# iter 2100, loss: 71.774783
# ----
#  our ug tane therds >un'nine fonsad.
#
# phes"anirerenty vind thas smeldamithas I I bos lorland Cuthe aou pesdang iny dI saroromdstithe datalak thitcellitet len, hirerlhak thacoros  an.
#
# Fne holOags alle
# ----
# iter 2200, loss: 71.473640
# ----
#   apsengocals thacmere I s
# inens inof -'z astpiite suevey wis t'm anysy fe fane and thturlipose agn, atith herathin thuint hricho'ns ga!liat anho u reesatss heougy.s ingont ay  he mange woncthe phe sur
# ----
# iter 2300, loss: 70.645289
# ----
#  nas aidusde sorlike wos misinosvils bir wird oj insiangerghy,d.
# imo he cor.
# sh qun yhherti te hhang hie shing ene.  erlemacgso hare urprmor vespeol avots ars
# aw dry alrgave pe hilsenl an?
#
# Wtide rat
# ----
# iter 2400, loss: 70.132543
# ----
#  d mewiant.
# "f tnbpan mrit anhe.
#
# It I ywifdrrom itns Zade 5mamwiselint t J jos a^topeeed
#  tha tind tin-es mlav. r j -dor fomet masipam @ot enb.g.
#
#
# replof ?u o. cry)e aon ruwelag +ore, esI thath abr
# ----
# iter 2500, loss: 69.879985
# ----
#  nte ptwuong kur bycing..i ding ang toth tings, are.bd fe, borresie tios b]iabtg, "ey hunh sis ra do. atdorbobohint rekisiat.
# f Cere as? folba potic a-ninw ntgen? thating.  "sations Rxbertung.
#
# -1)
#
# f
# ----
# iter 2600, loss: 69.858892
# ----
#  the cuops onep at opeintr, thew eco niide ant shede horat ir mecravh. t.
# I waofe af thirl asariodiaveenechre sow.
# d bfaditoq tiy donid
# . qacoreuwt masdeng an,, chacar an on ou hesmaot antentins ating
# ----
# iter 2700, loss: 69.635642
# ----
#
# honde verghe gedesrsycerthe simougicttiab erer Joffiqo sher-a.  [#he¨tet..
#
# Po_r, he hiss phitited Shetous it cor mettig/t pasipatelal, tou gat mick
# I ng 1 ky rinondile inkalg, yhe poo5ly, wint ate.
# ----
# iter 2800, loss: 69.723112
# ----
#  inaruntichit ounta3nthitcantiTpdesige, 3saly. topwan. Lwininsing lereble)de tosu hes.
#
# sephathiessabgers Iherat ig s.
#
# riruvebingare.
#
#  bhal, ag lopvemad hesshis thi:  heraf, ig ouneat is os 2y os so
# ----
# iter 2900, loss: 69.207902
# ----
#   wore<ptanriy
# gis
# pAmeicer tur (of.  aslot tEent skeent tordud.
#
# rourkocete.d witu rysterpange hichior uqTt meane.
# ceroal. sres ca hey itelitilfke heeciy went..
#
# B9!-0^r macist of and at wot at inlan
# ----
# iter 3000, loss: 68.980503
# ----
#  ogysenpr diputele we. eiltort ofreridite os fe sertos soenk kistaratimtude?dit viaot thementexto  pinithed omror caly,, thenpyof th enLfactt,  Tila mede ubalatu soly char tupreave coann ar f'ved thinv
# ----
# iter 3100, loss: 68.400520
# ----
#  rine to sungy he thousmore, eLingen s ce) denndee tpiabl non. Rorpinpang ro(ite ginn orversunts tate t'nsion tuby huto coss, ure sro'ng peatypriharide reronss inh tolbprer. th cwrkt.
# pemiris puro prin
# ----
# iter 3200, loss: 67.928389
# ----
#   the tire.
#
#
#
# celis ,0red thal vicht the anl.
#
#
# dcuritouc drexd fo peec.
#  Pe  Mesy we rhomy -Dang worrires Lyrrilgot mnche quvive angrendit."
# digily norf andt..
# ay
# pecin
#
# eXI sullu,t (ased.
#
# qetsis
# ----
# iter 3300, loss: 67.554388
# ----
#  od wor fooneltele palirg' tOlred thev set ar meot matt onbr toe.t af don)unctoas.  Loxury vostore det iard frenl of ou mose t thar tha- soade ade orpcorprerating an olipre, ahk't.
#
# .h oxrerk dikhf xis
# ----
# iter 3400, loss: 66.580892
# ----
#  Nfom tiswy.
#
# tec.
#
# I cherecwougD nomlutstemeve
#
# yhab yor pememe futs.
#
# I indoktive hafe sele poflateict halte seli furlle the wor
#
# ce cfope letdeps at thistafe sicem dots.
#
#
# the
# (t.
#
# poes wo depext
# ----
# iter 3500, loss: 65.822054
# ----
#  n tine is at.
#
# rerelweon thitamerg, nmintsenterss.
#
# I bine on lind mo.
#
# I bae rofubkeg.  Ihips, haththe ma divoulipd fsutf.
#
#
# Lhad-butosterfeud 's ames.
#
# I bachre anes-ton goono beame-ale fo ba ar
# ----
# iter 3600, loss: 65.227394
# ----
#  delid.
#
# Cancaprece alurtreraranveat s woue gecatsivreter umalinineract anof wonlede. t i<U
#
# ratele oraht'on bevintriod any pe.  ufe emeobove cof thac poec cickeely onde laterton.  SkeiCorant. trheraes
# ----
# iter 3700, loss: 64.676147
# ----
#  selnarat nor to I the foalre il an
# whepsdon  arlere lont.  jarestingir  pou dualito.
#
# be mepfoipla) thenterace it intuontet; pheribligsetint cinttisitholcfing oretabre hheesse metnibl2leltior. th, I
# ----
# iter 3800, loss: 64.306961
# ----
#
#
#
# on uonime che moll baMteldard.
#
# beve mvelc woofs Òhedma berad nosd ouble.
#
# Io d.tu iy bacthel.
#
# beane an  roay nob-if.  ams afm bopyor whe dale theat ad caf I capre
#
# I fings putr felrannam inw
# ----
# iter 3900, loss: 63.750545
# ----
#  aclowenen ag ag Tore wyo hens and tikiprinty ta lid pis :pancer ies.
# I and sered is if are panylte le being teike of tire omorysing.
#
# I phencor siand ccof t tud
# Igeblins samu stalt a.d anterc)
#
# I h
# ----
# iter 4000, loss: 63.439716
# ----
#   antsang.  onert of imerbuny ricfrniteowtosy incs Pugns, dectis twecitsilg hestoensist.  bits buto nd rast fnbous oucing come/es ating.
#
# ie, molbyonp.  y sSin tens the leact it arcult mefditacyibne f
# ----
# iter 4100, loss: 62.857624
# ----
#  jad onsey,ary insed of thed.
#
# lad of..  wremtalvialag ensele, coufat, ons otemere pathimesemy colly ag the mago withingart ans intsel.  sslabesiskins ensmece, a.  meikd on.
#
# pertoure mos inde tring
# ----
# iter 4200, loss: 62.262234
# ----
#  rcgeve.' ustere iug smligoel freasat oreetne to pade.
#
# lly of wacur, ricin cao fora bare ean.  youI taop mertle ind.
#
# tille fonine olk hitomis bemes has tith facw hontie prlogno rerne foexcirt pine w
# ----
# iter 4300, loss: 61.906122
# ----
#  eonr'nxyoww an wand then on if unde orsoar hemens inho d yWers of ind the thef, the ther wost hant fhhick the
#
# thon eny youl.  rimen radt on woms you muchobe.
#
# 8atroictriot ewoviriny rens hooltite-s
# ----
# iter 4400, loss: 61.454868
# ----
#  atemnigling theut fed ar inctithio to ond hev, tom tiveros lake, of ptitede are, a plolit of pomen if ag moS thas avisk staes of bhing hatie sorensedy ale?
#
# I Vo.
#
# ur cored beedlelt ord'ng, (n thind
# ----
# iter 4500, loss: 60.894064
# ----
#  ing on th  thes thy  maor and thicg yore ky ate cnacy yoryte(mesdinny y hive on wamepre di(t rat onistt?a ave med s wo ake. s ily to boot isy noncan athe d ar wode are ave tos yorl, yhemoprid d.
#
# Awr
# ----
# iter 4600, loss: 60.459037
# ----
#  ok inr oH to ejlicd indist.
#
# Nand with ar ias bo-om sice one lastunl agts.
#
# thas think, so, fanttat ine poid.  vated argoullo I prese buas thor an riLse.  th.  -Ylio(s lo ingrfty I w rheduting.   1
#
# ----
# iter 4700, loss: 59.970316
# ----
#   the wustoong dfciommate wo biko thith Thats. s't irlinn.
#
# cederting thik shing and inrthide mico theo Thie sund sucuraat.
#
# Iale.  hount.  I if by roncard.
#
#
# Ichaghing this than cuco.k Ogse in chily
# ----
# iter 4800, loss: 59.548280
# ----
#   and as moroblngerr vabesunls pereact intithe mat Ouveredrsares.  perenkrinke to. po dyowive wospifes AFgersed al anttearey yor costre the wief kelbuy mokp cha the norlantocsallUe ve yhet for intind p
# ----
# iter 4900, loss: 59.180796
# ----
#   liy'n.
#
# the lat Pom peas youe horer nad ofrighing wos have wawiic
#
# apind paddat'one.
# rukab hesprepem it to liof cowher ofy baclace top maud dore hack ax mallivei"f/ wol you.
#
# theculle, ame haa'g stu
# ----
# iter 5000, loss: 59.121647
# ----
#  k I that.  he wMthee se9nsth udentarebla.
#
# 7e5s hitend, y ins the ef thekde y uttchitis y that Buot 2otd don Thpes elet.a arf oss.  mithe.
#
# be miom ox ther A
#
# 5hgseoce.  " toueras. d fens of neve to
# ----
# iter 5100, loss: 59.127354
# ----
#  eale ataron yers an? hit wh cades. Thipl anntoe stut af toy,.  15'm nnrat hiathy shacorm for sid wit whoud juiid cerect sund.  To pepcrece.  Papl.  eith pres a aded.  me I eisiblil lated hyas "anr qoa
# ----
# iter 5200, loss: 58.822684
# ----
#  utba.
#
# I.  rosrich horeriaplill, darrentawf, woold, ongouthring.
#
# rion
#
# cew.
#
# Il foteedised sperstert tikon'
#
# Biwt in igdast actial ceryes.
#
# wighied exmmaldiont.
# Hhe ncarlwense in ithiig engar,
# ----
# iter 5300, loss: 58.670248
# ----
#  l tOling beak mings.g tou do fi'g or AWs palintratt cfoukig.
#
#
# Bo cof robuatingimug, lecs puagh nyter reshitgor ansel.
#
# 5Werevect foulw.
#
# wafes.
#
# tsot amineind fanget and wan pring
#
# if arh aby.
#
# Ucav
# ----
# iter 5400, loss: 58.657196
# ----
#  y sikgaselorer?  va wof on smigiss, are boplax AIs
#
# I eforg'c0 I ciopucuterepoomanat I bussd dowatd.  Calivetyinar shelegons, bion on ostrattaake, Fonting omatny anant veamex dtrens bedmind foones en'
# ----
# iter 5500, loss: 59.065333
# ----
#  s cereryor dive Eremtiins celpeisd wheraliny incant the tha krmit iul, lalute foe berooh ofss of ir in a herhess I picigtue han thore for tyitourd th urece.
#
# phrecprostarce sitiny, of thencele cotiry
# ----
# iter 5600, loss: 58.974868
# ----
#  e iat ins.
#
# to I dancer.
#
# ins selout rid erefre seo helactelrimed wraeats.  (Tha forshy?
#
# I y htirs ald dojuttoutrealianet.
#
# illf in's thee.
#
# 6hiSgentissanhitie bive oftinpkitis is lheferlingassy of
# ----
# iter 5700, loss: 59.143295
# ----
#  lo founch camy Iortre bledit it.
# oult.
# N+_-NE123ECtvants.
#
# lint.  Catupale spect inhellithen.
# mand nas soldenfe myNuthe do:
# 8+e7 jooping kong? blere) Hame ting chacity otd.
#
# anharch. d voversvensd
# ----
# iter 5800, loss: 59.473571
# ----
#  )
#
# sorgere bea tint rowtos to taublala soros I wharitauedeMd inctongt  on ow st bation He  abprest arerntal.
#
# binty ans (elf cy eVom.
# I woulving, igeut andavem ed it rtnres beltr, thane).
#
# decyouncy
# ----
# iter 5900, loss: 60.031462
# ----
#   art. the hlo poheces, in loMsiblidy.
#
# -fidereld.
#
# Mo]Ea'braty: Palut
# 'ntine hest)
#
# Cadeciros.
# 2nald and paobythopacore, it shaweinv).
#
# innfevedenteds, Ba s insings. tecthn. s Whet if ofering, as med
# ----
# iter 6000, loss: 60.288991
# ----
#  e wire insting.
#
# fot int mupe borned to sadoel, undinss.
#
# 7imum.
#
#  moChigdutdrer ind a sos coring walt,.  at wore camsticedmevithigm (4mfisthu lot pasty tyorsc awime whivlie pisten, pu word? 0Trivend,
# ----
# iter 6100, loss: 60.742730
# ----
#  tue ang mameme, 40-|817 DI MTTengnentd a teat "oure oo prowim wol enle, bakiad is thales nithat Pogtanive itreasest atdalrorsalg a moRy col coent anter solo:g.
#
# Ryhermemat| an gongaly ased yout sun go
# ----
# iter 6200, loss: 60.771431
# ----
#  edatorhtiang thane,  of pocva] intatrs curediin Mou inaricy. R1.7 awisor.
#
# thot is oumany andriond pacicw andivemracing-agd pait.  S11
# I Pawiticaande.  noal of thethd. "baliest the.
#
# I melabagion acti
# ----
# iter 6300, loss: 60.969324
# ----
#  gank.
#
# Spres Ihit.$ in fur od of one, ow beskine ar pisey kaxwinenex no goweres istitikeperide a doCgere.
# re anladi in timitfon that me tipagrest of, drexdec,s, thauny.  efry maf, hibucn thot thored
# ----
# iter 6400, loss: 60.860337
# ----
#  ry yorciin.
#
# Emalpse atedt rapution scoling -fo I thy tarrceve/lving taresulist stland on adere indiag interre coc ontistaynink I seand eancings.
#
# rrease tholat cere mace. hat it shevecu chet whosis t
# ----
# iter 6500, loss: 60.826098
# ----
#  Golingink oike in basis he thite.
#
# wer in in in. dourl[thert'ol, it rorlion To mesldore?d -malad higed bina, prorenr ora mereritis, theicty at lest anchi. (x
#
# cane thas the dion to you tyac Row whion
# ----
# iter 6600, loss: 60.784295
# ----
#  rn bothins cates derinemy the ions the nosterend oV bhe nod
#
# in i berke map ig pemead of dor in sormy wengorf alm isprestirat howhs os ar exeal (and boons king tomet on tod memend recked dranken nod d
# ----
# iter 6700, loss: 60.170916
# ----
#  bit ve sille coe to
#  er cheme andedutoungosutetill ahre to that endssial dof. toralytu avet ie coxtend wouk wfare yulsthatarcting wor igeur of nemnongore the as iforyyinice syand hojice soof at selni
# ----
# iter 6800, loss: 59.699198
# ----
#   fant-me tect cokes fhom't I of rephald (ovely toe heent reliny.
# top me't hore be thesentd.u. , rare tepreltiysa you in doom.b.  and.
#
# I'm..
#
# yorrs? I dane deees th I'n to durawing singrary lillris
# ----
# iter 6900, loss: 59.384653
# ----
#   vesemine as. burn.
#
#
# I her the penhe rentur ine licgrathing panary and.
#
# prendous enobrise domeRcon ideriritiie fouce hadoatdanÓ buraginere,sring non't lime dedamy mersent I-presy pe.
#
# as art.
#
# I'
# ----
# iter 7000, loss: 59.093262
# ----
#   to melts arnitl fo mertios an on chory inicins enod ar of remedesy be6 ngate baate.. rrenc fulicgeminale 8an mo kime in an goo peariskiots.  prerece nat Fresare in in in porava ats /omely. s the are
# ----
# iter 7100, loss: 58.901271
# ----
#   beats.  wo hopf are ulct, the thee fou shanss a prapy desw tad tort tomkingpsol dsutt.
# that that of miss arr ic paird.
#
# celtil.  fin colke.  and to wversidention ngom thithat and vy relift of rar/toi
# ----
# iter 7200, loss: 58.597760
# ----
#  itburs.  enty how. .
#
# esse do duw Ar ecmed.
#
# pienster tharn cats.
#
# lartiinete?  1oug unt thit.  C a romater.
#
# it cocorpory.  zalne allingros sart thoriccion me cinch haudire.  I the foussilas.
#
#
# W
# ----
# iter 7300, loss: 58.476886
# ----
#  ll.  haml.
#
# I punhal ryou wo ghy an scogras cver.  nom-mok them alt halizacing resins thesite pabeselfit mepm fro wimBclatatios anre-lis. cilasind thit lbooching ourt fortwhitisd ins rean ofp ot't dim
# ----
# iter 7400, loss: 58.079277
# ----
#   intare.
#
# lipy yous, o, the catill oudeeas. temel hof ars.
#
# li0n is wonkingmesitucing.
#
# sestiolil.
#
# assinh rearrevere pepmenanging hotston the chall nshing.  tulusses, of as an to in rereare ankelr, i
# ----
# iter 7500, loss: 57.690580
# ----
#  oet soded yon certeiranikanse trig toucian thakeramey a hy shanding out of donheece't sustiok re tand on win nomnine.
#
# Ie a indes
#
# Iy es oollomlibul beat.
# I s1I dert Af feres buke iraves righ of om
# ----
# iter 7600, loss: 57.504116
# ----
#  cut, whot nnath of me
# prerust cot shate hatiglali.
#
# I ire fremtithiofm chalt catto Iraveller lrolfer of femace.
#
# himk bere uwcimat creve hoondenirksot the atapty ard ind sthe siles ald ameper.. s ards
# ----
# iter 7700, loss: 57.221304
# ----
#  el souciontrigo prellit; ans lony aldat.
#
# anhing ghin one.  I is orssoncogenn the coeds arristiminsteFisting oc.
# Serout, plolen.
#
# I preblaste, ty thungacime.  if ind partt, thirg.  catt.
#
#
# hay de fu
# ----
# iter 7800, loss: 56.806088
# ----
#  olum eristin sicuntalm foim s ampuvy thes a krne my drund ind loatioo ary thekant oo semeresang tagivese to Nof a lecennend a buspointerned med in prat branan tery powenticiss ond ropjosp-meceditecive
# ----
# iter 7900, loss: 56.460990
# ----
#  overboort lal throf/ calllicmiYl.t. t'iny.  abket ithisk foat iverisgic sutt I cult thobibly Eofe:th fare than fore porkderle to in of on of tikit thorist in ald boringrivs lfor a thin' cgestere aruti
# ----
# iter 8000, loss: 56.122151
# ----
#  mly tot mopts iatqouting an so theg isys.
#
# I in-tomnor.  Sho cor binicgaslissed ot amlisty..
#
# alminest wore wo prot in to profcia ling ther a foug anthtoneren, Soe I waninging.
#
# ard if of noterss et
# ----
# iter 8100, loss: 55.827891
# ----
#  nly trat I me fissy lucmice Sa btinnsty fhame.
#
# 5eassing beschallvoons sooncind Vanher omife yoras.
#
# I the preve yoel, seesfes a bes fabeere seaoe. wo dist on extom o daakac ad lvelwartions.
#
# <ersedc
# ----
# iter 8200, loss: 55.608049
# ----
#   pivel.
#
# whe wick when end.
#
# I thae ut apm buck and paok but cony.  (bulise tas ofd wo mucd ut reeers sem.
#
# unt beres.
#
# I wich to muche ativess eer +ew the maty be tos past om. ensetism mach the wuch
# ----
# iter 8300, loss: 55.705124
# ----
#  ytrat me'singsy.
#
# Ser the sorstol.
#
# thing thes almeves irde and netwing loingermess ther.
#
# jene intolle veroriil to derellewt ade ate rowelanlist beregat ttine, 't ms rout forba the riseraaly memmoam
# ----
# iter 8400, loss: 55.767588
# ----
#  ug goile hact, moo [reco A there in adelrac, phice hellfunne mead hart lant pithe coser sires you in_singibaln, and themer.
#
# Thae sor caly an on of lig seethe To, Frikering porar sean].  Threc interte
# ----
# iter 8500, loss: 55.605449
# ----
#  rsly
#
# the in.
#
# athiot. , HSsuky cheal naplit fros artang it dogpanitism.
#
# Noop, dob pall-I: thareunes biribatu, roet.
#
# adequte are'redisar?  tyrive pramouckiog mads.
#
# nast as explaely
# yoiming.
#
# bo
# ----
# iter 8600, loss: 55.541290
# ----
#  se asing unepate to thed, or andelanitimy sollicn sasbeiliois Isuctuplount'ny  I culioeisg ro, inestevissestimime mos.
# Tha goonet oth.a.
#
# hik ngud efid in gheness ablat't of hamolinko, amprecine, c
# ----
# iter 8700, loss: 55.527382
# ----
#  ist'e aves
#
# >ssedineciutere aprouk mecomevfer ngrey.
#
# in Hechave fhes saskalre dosimadessress haCutemmy, have difs thassstoo domowing)
#
# rydiave segalnoe lroontedss ha camithaon.  to pfeatter.
#
# toreas,
# ----
# iter 8800, loss: 55.958940
# ----
#  t minkan't in'onlavitizaten.
#
# cine equt thensis tsoude.
#
# it mbuth of phas touth ca putdaternory hyor a pouout.
#
# suanemuts treare.
#
# ow mencuc
#
# that I withen't whingral.
#
# is fisbut wateline.  I gote os
# ----
# iter 8900, loss: 55.962339
# ----
#  est wit ans cictisle wiss ard lmiotelfs as hal is Irewars al thithe im tidine ane izsilul domeptry of the wise"
#
# Bexmeche thes I weof
#
# ther ysodening is spalld anercurn't one dod henses deal rochu wha
# ----
# iter 9000, loss: 56.201435
# ----
#  ngreveng to forytd Ns semecatit.  sy withenltingses meve. tinr coseto mesy irjtony to riogut cound am dited.
#
# antory.. shlnytary yllind ir wsand oenslaclitioudust Pereleadisicimescimedr planemctile.
# ----
# iter 9100, loss: 56.565318
# ----
#  , (okernintigila
# poulive.
#
# onorent mudalarjongU.
#
# wiken and ancaly.." Axser toe to sind of anded juds ont Reve ther werone. "as te hes reibpingrund than'e miords radelonas pe penmviovowing poes, fored
# ----
# iter 9200, loss: 57.215799
# ----
#  s ifumet avew the tith danedr., (desw Ñird 1suva tras ticuticf, the piche cer (Mepsered enses thich he plingris.
#
# test ind tainater) Iing outs like't, Por chend. " erhat on chatis, izad ithte ce cory)
# ----
# iter 9300, loss: 57.552762
# ----
#  d beestectorero protur qut ogre myserssperty zeyding wolfudi, of doove is do umringting foutctipilymy,, ty ofbl.  ist Th trade an I ma stove tysisghitisuly foess proforret/Wine int I doreto ntoer lare
# ----
# iter 9400, loss: 58.044903
# ----
#   im thibintund nadistare ghet domougs I:2A2410=062649 kald, dodmy you ic2.
#
# whidenc inecungat tis corpan eeseses.  to Pdour unonke to get cussavedunk, soug inm Tderstins thation, bhe stol whatiog.
#
# tA
# ----
# iter 9500, loss: 58.197544
# ----
#  s mitellalicamissed.
#
# dret chat s-acly, dave quede thes. I  fewseveckanthong hath strar of thins hameste daled That at.  Pare puspem, of-ans, "e. to.
# Le the destast simpp, twat bessteroct githialatra
# ----
# iter 9600, loss: 58.431953
# ----
#  aned in whebjecagitu, the hatsist on preshaludseÓ
#
# counp atictely, ugred and and thore Theto
#
# I ws ath andomectent. resbagace wating.
#
# rear/?d selmbtlace thigot/r, helmony of -urist pro)
#
# it the surt,
# ----
# iter 9700, loss: 58.426759
# ----
#  e. fow tedeem dovex to tharg. , halld.
#
# thore ncatiis inghsory proplorys mutersseter ngreventiwinites. cinn bave-cons out ofpre saviany in corlensinge is eplaaters fomdal merint trencty mert Wit'd pe
# ----
# iter 9800, loss: 58.455522
# ----
#  trel I praculs, inalsercen mothonion wrat a dissceliod in tece hat mop sor to GOaw ve Tentared intonme this,
#
# .  mompitit merpomy soul sald "e vistarectaly heys.  bl on sted.
#
# yo pcole is )
# I dice sou
# ----
# iter 9900, loss: 58.474138
# ----
#  l thaned mevestifl thath cÒrectititr mtoubuce wo tuos a ran toma that inssing ie thes an lor, the tanko a in sis d the uerterald" inte mor and to eail om be in pait atou vatet restlmore omead waide.
# ----
# iter 10000, loss: 57.903070
# ----
#  recouly pitilken of traingy you toud ITsacagre semect.  fhikian sor foim foth am be teat. propite iterastild torem ffop meabalite gind lial /fpurgainatorabsail wall butcutien time
# mforedurd an who  th
# ----
# iter 10100, loss: 57.479990
# ----
#  olde the pithent andsent.
#
# yrure a frome beselp 1Mankes', lgo I on me foud thy and melky.  a llalt ar poncams, mo buet dojf stones awhurtingoron ar car a llyser, of trat', munt than't ea suneglitn.
#
#
# ----
# iter 10200, loss: 57.243962
# ----
#  on't onsing, che fos reating thas I en) are mastan maictian
#
# I mathane lo d it handuvy dured foulsem ofe of andter sen arelines ine hast preaguns.
#
# altion er domemed yo msessing of ysueth
#
# rothisting
# ----
# iter 10300, loss: 56.995890
# ----
#  uck boprable chingtiry rionssilla.
#
# I pami dereladiny fheoting concronxcurfing tirt haching coemeive of arer troe ar. g realineves.  1L'C.
#
# Irenate inarf cheidicine.  I's mely in freind won. .
#
# 1Evi
# ----
# iter 10400, loss: 56.810127
# ----
#  't mokial sumiof a vyoup youromates...
#
# uer arlas rty nape facs Anden velver..
#
# Gokel ony 1a'.  I pithithle teDlary tome. 7m atepliy oate so dak fomitiblase dojrsg kithed fulligiblt hank ad dengre,
# ----
# iter 10500, loss: 56.550045
# ----
#  gounthere ithiwitine liret oe thhe trelnt incaca.  porcdicketuled ow.  wivitiorsasing obmente al bat youl arlions.  dowlizelst.
#
# I' thentefle.
#
# I fout tipe, cotod..
#
# suthes lomree then mat. s
# abpails
# ----
# iter 10600, loss: 56.466552
# ----
#  cigguls, po datiogs buod metigles, is are.  to I] walm frestit prosutty onererst-ans.  woutd.  nous you you dack in encinc
#
#
# Yanmiogs I ants cass.  mo byy theale nade sectroratny is ngrortywales.
# 7sm
# ----
# iter 10700, loss: 56.127557
# ----
#  ucorseas I pro hias.
#
# sonsdwali, funting.
# plike sletin tift of corloptiyes muangiontore my han hough.
#
# blicin] ansiwast.
#
#
# they semmndions. h ttrere conncinve pracond.
#
# sto peryou)g out lhorew:
#
# bo
# ----
# iter 10800, loss: 55.762869
# ----
#  h or_lissy in viok of wave.   rLecer i inecot browanecto car souke asclert on redeot ox tanthorenden'ss jut the an inviny
#
# andert the art tond the mathad of divart foncame fea beicteve harion ou pHof,
# ----
# iter 10900, loss: 55.608702
# ----
#  I aobef neara thacuse ar can whint antore the there, rith the calde-loryymistiou reseow qumcaee thera cem I I dran uprengming kepe hame cal ifadgisting on witr.
# ropesve as corst how ine enmeseae to
# ----
# iter 11000, loss: 55.371114
# ----
#  ebcots bofe, dojed.  is
#
# thism onelminghy whiver of mistylused of donkemions an ons) peroctyul ue the my e'ciwt. s sor bare.
#
# intalle sworkes I chate spin undor, an evess maliturelity, whe senessikeme
# ----
# iter 11100, loss: 54.952218
# ----
#  te ind dysus to foum-rnsin them poredollyous a wpike a you t wind tour cat is godonfs.  pay a dath int out anting the ctrige, tar flenananl of mudly 7ofles. s preeswind Dnos whomesinstirfian I thic eq
# ----
# iter 11200, loss: 54.600449
# ----
#
# I mee lory, whe forle wa thary intinss the montermentornhion.
#
# tho ngrnermos yos that't xham.
#
# -tous in it't trat, on ind is an sor for core.
#
# ryest pthomad the mors speo and of out wes a chive
# les w
# ----
# iter 11300, loss: 54.316072
# ----
#  ns thotu narer?
#
# Somecing,
#
# Iis ky thatrin -6fory?  fose langerch patalt thimeshas foct of.  There ginessing conle tites my is.
#
# I thabe utifiene consale and che shaik.  2/m.
#
# I me.
#
# I whingprevest
# ----
# iter 11400, loss: 54.034370
# ----
#  o cot.
#
#
# liuns you mytion.
#
# Ianate?
#
#
# irt soryse seled eqpis yoes woy stanpram mooy thot sow des urgoal.  10.
#
# I hand.
#
# cat an've eroud'n the the mut meap waman mate ase uy nacred inpualt mysurd as
# ----
# iter 11500, loss: 53.843283
# ----
#
#
# in for leagting thame I a toustion, hizes my anghict imace and spat tone pronkeres. 8
# I cokeny rofentiwy the deml eam_y Sow orplowwor I proaner.
#
# Yok out.
#
# I to that tould I's intidtemmmextuy.
# re
# ----
# iter 11600, loss: 53.991374
# ----
#  ie the hand thess do dat lof intAmion forlip.
#
# the tith shousidesty mecene to ckber.
#
#
# ant weny ma turires lok one hate, tos.
#
# is ilatite and thesd pink.
#
# I a smeshalstalsisterifies cant likersing.  n
# ----
# iter 11700, loss: 54.067838
# ----
#   krormanding. ing theme enet able cot whikene the a frecaieg hist.  I tik ogtiwine in mipplanste batd e e.
# I vesddonecuris ony eop reconobo woe re.  toe-liogw do fittite hind an.  be 1Hly ald.
#
# Pay
# ----
# iter 11800, loss: 53.930112
# ----
#  ing, frich wicr.
# le un lition Sor ofes it..
#
# (pialtoen In whitizedion.  Hoslyabonistiactict.
#
# oe wimun't corat. ingpition.  limise oupreosicgace tre my't tou qwork juvather.
#
# RikePcotid.y.  yo stat.
# ----
# iter 11900, loss: 53.904571
# ----
#  r cadeles, ling and cis in con doug.
#
# is (by expiogels the lacce fantices.
#
# imneg makiteragip of somernive at they.
# stendor that hick Prewion.
#
# pothat.
# relding, al, yous onsesghans erong am ts ofs
# ----
# iter 12000, loss: 53.868844
# ----
#  eclpanace sern turoupling id funcoryy my sopplam.  ros the this sorkicgy a maturlsing, ifrobuning.  b stry-An montingnornmuap.
#
# I you demselt og sult seal..  soanss and of elent hyore wus whing ming
# ----
# iter 12100, loss: 54.320967
# ----
#  highiagpriresnoctrmoul morke nothe atre as
#
# hem
# Thera.
#
# Sond muchised digem.
#
# Iiting.
#
#
# the edenling one wian I suntrasbing methact and pelappty the ingow.
#
# of gecthe mebision the  amprak of thinati
# ----
# iter 12200, loss: 54.322100
# ----
#   wimkivf my incily infmest. Ax the not ot 7Is on maaticting verigyt.  at thocus wigh whes whiust, celping ay mnolkil compcaly CI waupr entenc cubledation, the ex expubutitise.
#
# scid rowoist "3op. of h
# ----
# iter 12300, loss: 54.594375
# ----
#  EXB iDE:86J@2 wyand and tom
#
# facde.  wradeerg feress.  The sast oct to; eporenctionirush.
#
# con andsa bounce of yserestion fasion.  Mains the sied.
#
# panon craginting oveticating sor, Greenm.
#
# Bure-nt
# ----
# iter 12400, loss: 55.006642
# ----
#  arere to ssing
#  go teremocucatedies intentime mmored a ssoaf gormosbalyce MZom, ant cunt is price lyI aly on olcins dodisplnion coaly to have on I chact.
#
# Pronc
#
# ot utol?
#
# 23.
#
# RAwhe ling cuncilser g
# ----
# iter 12500, loss: 55.603671
# ----
#   to rigg yom fol sexproPy to urtidiast peasy and thacining itersed TA culing havenkind, word?
#
# soreera?
#
# can dised (nod far hood a arut ttoup miwing:
# ->.
#
# AMM npeuvs a dear is sisal terfund the ces bu
# ----
# iter 12600, loss: 56.010224
# ----
#  tionstint Romime tharelf.
# the hialtoremerming-soren of - fsantiol, butroudd inel luops of consterdezet on woctopreft is moderiteret"
#
# Yfelfty, beive trof an trore, both.
# roeftainkigranter (odenter
# ----
# iter 12700, loss: 56.462705
# ----
#  ses betterston0 selitt/55]. 8et sors instname nopput ny bercges a becil.
# I D05X T a fis of, extralnoen the: fobpivest to evess plintfertur be that betal.
#
# thore to to front mastrlen cot wholliting ut
# ----
# iter 12800, loss: 56.724804
# ----
#  sildy, prorticoouad dernckingy, tres my as a cuntial on Sam: thlide bbing
#
# cantertering finchingalistes. "isunst inghenthe cast. "-Arapranit.
# OtRxto pert to to cheal to hart escel.
# " To eint of mevan
# ----
# iter 12900, loss: 56.944629
# ----
#  tnont nenplerors fully deaned
#
# arectinion yous gose't ars alore a haluner, alle, in proded that or bags oRter 500NNCLNMUORETAC1PAvATh""
# Aw Nivected a arted reant me a cougg altultuck ins dating sectai
# ----
# iter 13000, loss: 56.984060
# ----
#  s veric malfe. sowh to jet alf puft in atery conds" wind bll4c omamstibati, sere abousisen.
#
# I has of Ipw roreds non't foal Jafl worof rofties tos. [nCiinm prefoure in ramU orte, hive dompiric.  srite
# ----
# iter 13100, loss: 57.064409
# ----
#  re an ty isvend. m
# Fee int menster art or and and as seiths und buot hake the my Fewaing to be cepply putoratounter riker the as the tnevesel.
#
# I meat. tiit ins ase a dichy hapl fwims savel cones sur
# ----
# iter 13200, loss: 57.110575
# ----
#   tinh.
#
# the like sut reins ribist me it the rient
#
# acarts haowy ofry what lexed wamadest anded as as baalem tnyse
#
# thy thount. s that ofeas.
# Stilktolizeiorroos.  of omrethare ald foubl kites perer
# ----
# iter 13300, loss: 56.553375
# ----
#  to thin you 2) POA |  NA
#
# A
#
#
#
#
# the abous teithy theat.  to haly Ro plith ncer racur the teaty as Gojus ttoon.  I phiply
#
# I'm athatow sist "1.
#
#
# beem RI wA the the faths in farts dache no giblles, im
# ----
# iter 13400, loss: 56.153665
# ----
#  ste"
#
# to the farest con
# 0ithinh you rpougting thice ind cor os boke scof be wime tus We hendent weover abtaigy and kerey seextife
# amy amalo o ltowers.
#
# Theilira enchouged plogike.  a dand nobPees or
# ----
# iter 13500, loss: 55.954609
# ----
#   it that onte tasss foriminv a conmisirg copea isponithisgs than sterf eralo erroin toulf aly.."
#
# Bimpanes or iss. bodes. .
#
# ot is cass an.  AD>N
# pis pofeor.  ass.
#
# Hyou the extrot and an go litist p
# ----
# iter 13600, loss: 55.712219
# ----
#   teces they mattition oqual of i tormianter ariel likg conchiof I wrevaret ingivaring?
#
# hes cablling cperpo that on whove eplei teraotald the fevitued
#
# I tagition the move lied enaablafatiof fund han
# ----
# iter 13700, loss: 55.520935
# ----
#  achnorfirllt pery berfk.  sit'and tem seem nghe to detibiver?
#
# it of thakingcitir tyom the usgurf maticpecersmung permapt that e-f dine foulm coul four on wart sVenoul woming bet sold warat us piteds
# ----
# iter 13800, loss: 55.311665
# ----
#  dhant of aldengastiytul.
#
# roblideitingy.  N-7mu wivec be orive themevy, out couthivltity.  crtes not?
# ftalite.  deantere ary read itelfkant ther intod ally
#
# I surmew herer they eMtoup? but tas the n
# ----
# iter 13900, loss: 55.232935
# ----
#  ofstaticA.   I 155 N45 N 7 tries ntitcy orcheady, yanter laln an'sh ofre.
#
# timutsing soupt in cfamealatiatimut, p tupettertiad that of the velconnaftrant exuuc buedro pomith os esveplioy
#
# hojrern preg
# ----
# iter 14000, loss: 54.917792
# ----
#  in mathying-ons an omelalagapt of instom to qutita.  youtore mallenticn.  burthecutizy arorirg.
#
# sterminnainiadoss.  the crichilil in in otopticarer uldsers andunter antem foothick., whende lo Are.
#
# ----
# iter 14100, loss: 54.574948
# ----
#  g.
#
# foncion thith pereed (out my conding.
#
# I rangis cuction.
#
# xheminafe ourtion that lict reering.
#
# Afrenity.
#
#
# I fhrecting ar.
#
# I meed fied ysef iracy ody the ar amaruoras thet bacont.
#
# eansts.
#
#
# ----
# iter 14200, loss: 54.423311
# ----
#  es the foiniston ant courtia is rike tolstae thar crevhiact thides my wcok?  a m'se thick is exo uncy hor mapriig alf bes is whatt of the lond re.
#
# Chonkafe I I (Lhea int? wis wore opboen ifraces anc
# ----
# iter 14300, loss: 54.191321
# ----
#  and so tha borten:.
#
# I har enpink exurive frecral mat on thige the in I whick.
#
# I't of litreraca at mes of for exullentnonm gectory explaation limere the thitere I woof lire.   e-pon'e tresce ablelsur
# ----
# iter 14400, loss: 53.779782
# ----
#   to putitcind, danslostercled wayserring apleving withing lout rlaciusto scutcan laglispliont ald megutinn(slect hact wran verisd to var eruchate.
#
# adreaility you haacingy curt damact/atens whass.  (1
# ----
# iter 14500, loss: 53.445708
# ----
#  rition text com nove be thy lis thest crenarele sI dost as surm.
#
# thas comanew in ave tom berercbout I wommity trood piring.  Cor yne lors of to outhiast saod lighs rbal't of i sahe to he. .
#
# jorkanes
# ----
# iter 14600, loss: 53.146681
# ----
#  decoli.
#
# We bacha.
#
# vampithing bhicf to work  of for lyod stowich the epeale tos paredve
#
# Pare.
#
# cond ins incomingerthe thanctect
# as baky toss bolliytrainizv reand to plomistoonan whatm but be the en
# ----
# iter 14700, loss: 52.842133
# ----
#  aelaved.
#
# lost orwen anem, ryounsasly ar it e. roull an mok.
#
# I aes the eboo d bue but coom.  my utory lorking ial yomy wans as cand and he.  I at of of havon.  like walle cark? mon od uthe Sgave I w
# ----
# iter 14800, loss: 52.677410
# ----
#  ap likr fort.
#
# woule promper machering be, dowhecle mes I'me hat thoun whitu bopbored.  Sog qutexthip bouctimlledionmudume.  be suly it.  a tund anghel bes to noum sour (rrene to lakere.
#
# I'mtrong al
# ----
# iter 14900, loss: 52.853929
# ----
#   paverst workenk proge't of bacriction mating wat wer on that cobit intort teler.
#
#
# yous naw that bred descerer.
#
#
# athings.  endit pnow of lfow gown'me for to mes tink mey go cumbort a bing Cark to
# ----
# iter 15000, loss: 52.920691
# ----
#  y copetitied and be seve and as epdastens.i som an'e/wite werd that sourt of and an oam cos Aldessern arpulcu samlallar.
#
# ut southy me't wand inat thime, hold gichibrtner.  Avery.
#
# I de soft wor made
# ----
# iter 15100, loss: 52.807991
# ----
#  arcin't ammucouricat.  I ventingtill ofronily tathon.
#
# ea lail peraln.
#
# od ean'g the comm ir a aroand anctonyan perives plobser.
#
#
#
# I hagring oforssalelagugert ore wivense bowiol, soullemion, muipcan
# ----
# iter 15200, loss: 52.770046
# ----
#  it berof nom to Ton Pasporsmus ganife, is the wosg netere, and hove at wo hiout not thit'.
#
# Komuct.
#
# Ies
#
# pating whics an a difting.  abtan't coe sis nepreant arproque rok to out thaters diou.
#
# sory
# ----
# iter 15300, loss: 52.722627
# ----
#  ce al to whe fituty to encund gabcgicut of yhat haveve woud any pert in oveven.  Re encalite hakasion netrmonko.
#
# Bumlavablaling pextrer sit ondsomal. thictive ans goty ^qke disting, natint og of mow
# ----
# iter 15400, loss: 53.182504
# ----
#  e tincting tremes extior irexitiome ont ist rowicilerion.
#
# y mey'v cets.
#
# I a gotod shersecioug wrivess oty lade proll anders encikingters to be, if of qored cacmoupatinis is whene.
#
# lroul sinsesales
# ----
# iter 15500, loss: 53.196225
# ----
#   kos_ egised feoj
#
# perutel.."
#
# wlion stul Ridecting whies, a tea axly rowicutiameting and in precinterctists sronking."
#
# Hfow and enes io coter that do share lik ifctist an a they arsich.
#
# mutered"iol
# ----
# iter 15600, loss: 53.460867
# ----
#  ols that I precemiren" is hang hariid mim epe of forme ctnorest.)
#
# -schiergs.  as reven'n omerlident, fand us pecing but somything.  roamnal.
#
# WeNtion, canth sefalls.  ingtitver them.
#
# 5.  I Mv^juos h
# ----
# iter 15700, loss: 53.870403
# ----
#  ctiss veligemm an thing gotoo antining tertincgsa clemelly mave fopu fitct. Omesh Ltrse to feep has hOgkig echary froverivanctrong al silled
#
# Rolk toys.
#
#
# olllieg bocle.
#
# -whe dith Pgit
#
# mering my a
# ----
# iter 15800, loss: 54.470850
# ----
#  -- Winn
#
# llobatht.
#
# shat is -
# teins sped?  fo bat
# trind tham Chat's shald
# bike
#
# -batge.  a Thine.
#
# "I mithinke it my a sor.
#
# custornthe to the salj.
#
#  oldy no bl--prise.
#
# sist my dicllig|. Pbrensoner
# ----
# iter 15900, loss: 54.882571
# ----
#   al magerart (necint selvech
# I hfund dsarkion.
#
# sathe, hodewens of tecitine. so rofint thore.
#
# -huldikipty domemlys dre mate ma to anltiou,?  NAOOFOC9-NE A0n 1The to has it do nond civess. Amic.) ilf
# ----
# iter 16000, loss: 55.362017
# ----
#  neste intes Rrient pothes.
#
# ditvaigita.  in everot.
#
# that quond ssarstabllis a cunky the peal od?
#
# fimanciscinist ant story I wivit an ince inors.
# izl P sery)s goniame patend lingsscition.
#
# phtes on t
# ----
# iter 16100, loss: 55.674198
# ----
#  sioustut.  busexit bithoop so woed arust reDterkavect.
#
# I ove sampunsansiby abal kserterilmputterfifting of if whing esterer of lias a cyout-so ruiblances thy of the hy.  re dist, batha ariceny.
# ster
# ----
# iter 16200, loss: 55.884093
# ----
#  sime canseraÒtrtas.
#
# whosped agronchorore is Alouge Whe abuating thingubest it prigbutereal atumenctime, t id deaketh apatite.  bo pees tronites lro htac cersarsall Ònas cuscent.
# -sherming vasbation
# ----
# iter 16300, loss: 55.944979
# ----
#   han'niont checaticrser reRtsing hilingeratis Mg
# the.
# nosuobero, s irmed, in meal fan tiboug dectule, tatiin comate.  wonktw. )
# I asts hapoonsoy in tik in Wohtore cot'.
#
# the haoded seal sid Bivion o
# ----
# iter 16400, loss: 56.063293
# ----
#  e dran.
#
# ANtUive recter.
#
# Ly Ñiad a dheraboug in bl kex a meciontion. Thiiv, yne high I toproot coraunce to domd!
#
# Indey comt it feopy cond as to oresen it.
#
# engr proing 4is rely mye? on ut compandi
# ----
# iter 16500, loss: 56.124897
# ----
#  eorale with hen a the baturothe? -
# thut Cas dones seconalks sean no fory that in ones bothe ticorernas ancers the id.
#
#
# want 15"28s.
#
# lyows cats.  in tod
#
# hats prots, it .
#
# I inde bulice art fory tiv
# ----
# iter 16600, loss: 55.586668
# ----
#  lkt. to ust heaw.... thede rachsey anker Janku pahe thats.
#
# Tiesthing" and borionmd.
#
# Lthisk w
# the fitoring.
#
# athure of thebalp telly sese.
#
# touge to delving from uvestiw ther an en'e here.
#
# Irano
# ----
# iter 16700, loss: 55.191839
# ----
#  ife moserited be preistarsionss trerned grengirition nob sill thorut im an of youry..
#
# can'. whemut gink.
#
# mo prothirupasers, stere.
#
# liking ist.
#
# the af the thet Iwitecy riod mist to doshale threnti
# ----
# iter 16800, loss: 55.009299
# ----
#  Clint for pcoes ut that of art ineciborale?
#
# thirains on hak cont to and exelist dor alo..
#
# rnyeertum a pryow makertooupd.
#
# arker^e.  re, a fror hise to and os a puteala ingre maes of and fould rae h
# ----
# iter 16900, loss: 54.790337
# ----
#  iy', foutuers.  is io the to a frave lase ithsatity?
#
# tha culilytro miale shelating to for velfed abatiin con mongrony wor rencont oats a thare likingion tration.  otery.
# As eseaden, han incugrecal.
# ----
# iter 17000, loss: 54.562655
# ----
#  md straady!  fors frastiy to thecof.  a dingor, in lates.  mom be mest wawe enemf.  Comy ham  aruns mastyou the vaw.
#  tpatt.
#
# I sjeryth.  all 4Ave a've istronistwfiont madule to mor aprfod wonkiftarin
# ----
# iter 17100, loss: 54.394568
# ----
#   wivenched peeching alr al ant that doysed.  hand s a aidesce seriescuremeds weade.
#
# I kis inapachigh that a ancoued peatiol deadesn't it fascer puthild.
#
# I dopren comralater thet of ceadesting trore
# ----
# iter 17200, loss: 54.303393
# ----
#  id, you hisss smiratain wo fine coe proverti don'm consaring thes plut thiusty mecich.
#
# Relarins flor ineant popingotians mo yov a thine prathing ouly amed and reired.
#
# on thersithe workares in'tes
# ----
# iter 17300, loss: 54.012298
# ----
#  st in it that and on thesimemt be 'NXB
#
# sore inresied of a searhersle is the micess.
#
# ifut mect/netis (lade.
#
# or papotet of to my sothy woul fouole enlad, sorse.
#
# I grat of sithe pkynerant unre it er
# ----
# iter 17400, loss: 53.686549
# ----
#  ing
#
# of kundythating med thene lilety..
#
# Imey hevesill coloc.
#  for cas be.
#
# om comen'n wantoring of like coull selled be in urpterks-recation of theshe epale.
#
# lanibe.
#
# Thin merestion intis amited wel
# ----
# iter 17500, loss: 53.544264
# ----
#   recarrt peppiapdemtion sich pranm meatinasturm palons sake in as of the in wthitert.  bus Reraor it pensabiny cinet if thest wvike Ial wham of thes, is
#
# hiwe, nanes enche.  wibbinest.  the tho-lhith
# ----
# iter 17600, loss: 53.316340
# ----
#  prisale heent if hage of and. s in a perererre in the hiy y ollle kad my ingont thy devest an lithe to dsech that rade on whing whintare that ser ngund apenese, Lswtrigke om ad porensiend.
#
# hogelted
# ----
# iter 17700, loss: 52.904974
# ----
#  lompane it eChamm oms and to whtoll aniention the exd_avity be.)
#
# I by of cact.
#
#
# thich and cogaty haver verel e't ove paytrratian trols wilki20-rense,  basea serionating.
#
# sommang trored I ma voje t
# ----
# iter 17800, loss: 52.577682
# ----
#  on fis
# 7norlitiwiotenfr.
#
# you duthay intyond erome
#  thustert
#
#
# the eScoucials.
#
# There bucifition hacc roonhtront ancn the echef terasing idserion, conerething Hartiol.
# I prich a, ware healde forupli
# ----
# iter 17900, loss: 52.265300
# ----
#  to work sut'rede teyt prottqut.
#
# weration.  noven os yextcing iftemedblach ouhecting, hidne illy Ebjedtry?e an be chu ssever the lisilbora.  indeing conhen) longenes olras. by in, seemction.. senh c
# ----
# iter 18000, loss: 51.962875
# ----
#  ottinate.
#
# velser geeat sheduiks matumeat onfing bed-dis.  frond mexablimes im ampottolithouth like tely.
#
# crilfht ectead tallink eaghe loon't making my'cging al meal sput you I teragine lon' linkt e
# ----
# iter 18100, loss: 51.828616
# ----
#   onginged.  |ur armarbiny. .
#
# I  Te Nore't dald I dentencis my thich ars boles foud aythion mate thenstive Ofouk coms.  I vobne.
#
# dower theur intinelel handers, cuck of I was, I mantirn dill putsly w
# ----
# iter 18200, loss: 52.061868
# ----
#  hare legsis oulr nobte sefelsaat, and you lea tas surd heriogbour wastur the donyse trouv Isdeabosporypatemm of my heve to prof a klemfow fit tericam .  Twance andction.  to preldlaat.
#
# Ar art of tyee
# ----
# iter 18300, loss: 52.072414
# ----
#  s. .  as in is inssicat vas und enechto cer^jacf art domen sith amm. Toulke?
#
# Ue smart imacersait rijelboon suttionss at in thir sog my thirkatilgze treriass and poantanlilime anle arly bus)
#  art not
# ----
# iter 18400, loss: 51.973506
# ----
#  digis notrion"
#
# Hoduvime, olistsels doplionstlo eryoupd hove't mupcible ialan.  TTheactrecm, ssotheresnacle imty ofling murecoren thacgs and diok an the. k t3 +ngey.
#
#
# sanoorios inkis ur olobac bimp r
# ----
# iter 18500, loss: 51.915212
# ----
#  s, eis a sit mecidiven ut afarivitisgrialistiontacelant orfolln aby.
#
# In nonte"cobt) gisterssion, imaply!is the to un roruet rocer) bother, on.
#
# thiculopt wheswrik I crasesoryally, somythive it Fave
# ----
# iter 18600, loss: 51.880908
# ----
#  ordeyou lraks cormadend able lactine.
#
# hane selcshyy wowh sore demallent SDarmare bo mered a datiprestuln."
#
# framully and ent'e madels.  hina.
#
# I'm
#
# fintentionanenl.
#
# I whes thas va furd cillser cfal
# ----
# iter 18700, loss: 52.328799
# ----
#  eriancuns if dratangong ropdimjiomscaresh.
#
# the whow my the cule e1s.
#
# I 7 hand prading deabilie+ youd diglne glime youe precer is and uply.
#
# aroresterning my probrothise sith.
# Na Ca peshient 7nor
# ----
# iter 18800, loss: 52.353628
# ----
#  y 't halle like in moppkelving the sobes sunsern)
#
# Incplobionse idgrave as but thing?
#
# /han wore mace.
#
#
# pe itrown.
#
# the ust is I wast medoned I intiot a mach at wooespiamsirean abfa arat apred art,
# ----
# iter 18900, loss: 52.626503
# ----
#  ve'" and exuigit beantion al woress ousevers.
# sor etrelaving be to peany.  in pelarss..
#
# sind bevcol I cinlrvasing a borivatis  Copreang of dingry Ny og ngod.
#
# meact icraope make ssyonger for muche
# ----
# iter 19000, loss: 53.035173
# ----
#  d prebr-ab/oprent Mik. "the rajest? u are ut sowe.
#
# Ithat selagey car, dopatenting lhaing watersers.  Pthy  natring piebing (it of deation.
#
# I lotr, macully qra cen han of Shat evating monch?
#
# bond b
# ----
# iter 19100, loss: 53.638441
# ----
#  ood haCn thisuors of Preprece ustr?
#
# I- I grojei avecte erictiry do bolly.
#
# (P/LENECEESNO74
#
# M2--, to 7-apartided lout disers) Dy os on celloch magring grepltv opled, a the the Grontnor. 'n Kith romp
# ----
# iter 19200, loss: 54.058060
# ----
#   for. (seagiasy, to bererely ant wos the eaty terpry."-"
# -st pforeshs, be?
#
# inctPeripinuns trion.
#
# I was uoltelf.
#
# elpting is grifas intway hithiis idsear rorler.
#
# cumurren't comac.  sorad, meaupion m
# ----
# iter 19300, loss: 54.534065
# ----
#  ron's wher empanln re.
#
# thystn, I 6063e tamken Rownacut feaver is un rave to of misguastarte. oncans is it.
#
# Jondigingegty likm lor<ars likeinting doolo my on lart mive forth and is batulif the cringr
# ----
# iter 19400, loss: 54.897777
# ----
#  wind mo atere paatied
#
# The nocotion.
#
# the tocd know. tyod, Ainds asainting Than lex af the (edere'ptelicdio)
#  -wores, whary iveny my pacumester stat.
#
# sering.  ">D Thive the fet be tictist about in it
# ----
# iter 19500, loss: 55.074690
# ----
#  plagg. Fsunm me o tharaghomd cang is be chit wemess ags No scoul me diticaty.
#
# I hand to of a the wolmelmpoog estred ineed:
#
# ible tein.  on tosensers of thine reintinging thicpysieg whate.
#
# tarkimg| T
# ----
# iter 19600, loss: 55.161709
# ----
#  lle. eptine.
# din binse. /- sisty fool tnor not ie Cotacuterg itor ("Am
# pes donsed remay cortyroug scle deciethir and t Saiter in ory mad relergigine tod sobigy cfoncinion gogractu, lis thet be my bed
# ----
# iter 19700, loss: 55.278012
# ----
#  atures
#
#
# Fely ratoond benake wit in of a Cilulitis denyse care outd.
#
# or don"ghtics shey mas lalk of thenecloXg, in riclysuld dechy ivivendo gate inthersed houds.
# "the mace stevethionant nomed, Agd.
# ----
# iter 19800, loss: 55.361707
# ----
#  co t'rer as thes tronf wrate---sent todenteroreviy do mave olk.  tro '(fraly.
# ...
#
# I I why spow tuand, untiont a theren_, dists pitictirnints
# ----
# iter 39000, loss: 51.229553
# ----
#   on what that cex what to from
#
# soutionshe.
#
# rexuncinal quart spogevions and of a projondions a thinks my ma arla, goive intesting, was my thensiwing.
#
# reantily the ageat a enerAful fations thise flow
# ----
# iter 39100, loss: 51.584364
# ----
#  ppter your + Am 131 80M291 "9---
#
# me likery-l-fby.
#
# f?us, DAfTind racesting.
#
# 4van the. say grobintialestion, aretiof food out can dyvaticisct for tidend of the cad coeuche and hild thiege) blocoplest
# ----
# iter 39200, loss: 52.034192
# ----
#  agremnact walkould bece that, for like an bery Ameash the the ÒA VLTsunks, soboltives? ty.
#
# this wateemraes ao a dissul to the rasabelf"iaillsos, the hevace. my spit alk liess.
#
# Wother ouher, as but
# ----
# iter 39300, loss: 52.261492
# ----
#   naliontion bboding 19 904 (HEH A OTBM^SNSCECS AMO-= I Mas deat.
#
# Whiple.
#
# us a git of de, tysive batialdrut forys pto ullre on Myom ounstreater thoo it breaglic.
#
# I nave simpput abeany baines,
# ante
# ----
# iter 39400, loss: 52.363609
# ----
#
# pift, drowapr, sond anshornforece le. any.
#
# me chhougin.
#
# maining ratice, of anver. So ave ovitss beested comcond Kiol?
#
# nogloru.
#
# yoursett.  to manging frobore toungiserecam op ie licts and for ad
# ----
# iter 39500, loss: 52.402603
# ----
#  unery.  wo be houd, tachy delf.
#
# whe rits soryoug varare.  I hat ireswenserol sealy sentI)
#
# rgjelinatect of that, gind amle love, in intendtion forma colfald (fore ard
# Re. in slert Pab my the beiliog
#
# ----
# iter 39600, loss: 52.538719
# ----
#  to evit youre?
#
# sentel ange.  a leat, complagitis my cading the out the hallos pooften.. I the progratill, bimaasiping imasener andifurs of arred objectunce forirision
#
# Whene huutomity thlustury of i
# ----
# iter 39700, loss: 52.039498
# ----
#  .
# (versils lotestiugrer.
#
# I faem they a pore th to the pucthof.  the vellant. s the Uralingy.
# jeale ow.
#  I breterat a folle but scunternate.
#
# yoh Òsen't vy whime enambut thate "hore ictagre that wan
# ----
# iter 39800, loss: 51.693079
# ----
#   ly of exptots.
#
# feide traprour afle thive.
#
# I stery you sfade.... shore mearimu arl beat.  burkipl HfÕrythin tutistens.
#
# my n'ne todess- lowreve unertition.  sa al nok not work "y hand pren of thin
# ----
# iter 39900, loss: 51.644663
# ----
#  odmarity, worsilay the expint 130- -0:/67 =04 a DLM, POSEUTEXF
# thaingan hend aly a nen goe pradergy.
#
# stuld an 1
# The litse to and therus araligich undoas on as to hode  it Enives of resuntre. (sseresc
# ----
# iter 40000, loss: 51.526802
# ----
#
# lives, the imsizuld some the mavist arowane quaduation, you lithange atiblivins thes-potime we denteden'm the thinks of texking, a Ganteresy and is thy dot.
#
# no Rgond iimest
# you the sally conimaln i
# ----
# iter 40100, loss: 51.190108
# ----
#  ut out poupl out hald wrjcoul abok.
#
# it to could comject dore matalous me.  hyou fool.  xtraem.
#
# luthene to detelened war.
#
# unrering to fut mes.
#
# atratend aviptinat. Ires I'n twing equmerial strciftc
# ----
# iter 40200, loss: 51.115083
# ----
#  re, a that do gheid
#
#
# mowe litvart of stove. Sovater, watys mensthit valbousted ring.
#
# betablic in ally to ingulfe.
#
# sepethy, the hax it is cans pitnen sicremle concen't adoss arcity.
#
# it of inserat
# ----
# iter 40300, loss: 50.974033
# ----
#  you a kie thaved. "hin blitoustument.
#  21
# -70.  omat delated puftor lare to one plangs.  I foncatidijatilgs.  inaretho muuplient bewald that anhwract ligram ie.  in boferouding me.
#
# yours.  I be strue
# ----
# iter 40400, loss: 50.656839
# ----
#  on.  a pandoresten and sherilich sometho, domar an teximess.  whese, alvulem.   thive imponc on the sily me fory whic ditpuctyy an of ow io wracusare fudlen the lor whit sowrouglly me of the linm abow
# ----
# iter 40500, loss: 50.374500
# ----
#  ection.
#
# have the drerpermy Or of tenle.  ardsed htoultew afters bethou?
#
# __U__ 10. S'p tevorer conchaly onfily forme matecing tens cut a mies or workin the enve progly wand to or os hike whime..
#
# a
# ----
# iter 40600, loss: 50.213262
# ----
#  m in cas what deaget whine I like
#
# gride the cat experuentes uppasent like shasa withing.
#
# I can and pewingoon werizl them nee ibve meli, cantrops inatenelut whe nop
#
# sherthizicing, wors epmachieqmmic
# ----
# iter 40700, loss: 49.980077
# ----
#  whis any racuriof--tuifl (comal thers exchenem.
#
# and thac and likidiny I vfin soljecres hove in sgeation, lixs.  lroking woly.
#
# Is the which rejant brech one, like powans mide.
#
# my a wus can amed,
# ----
# iter 40800, loss: 49.520643
# ----
#  all) of the co ile thowe buts gaters nom in a pernering pe a linternpe redes levent pecal womkis I sop en't
#
# yoe it wand expeas roble convering on terincity nake, rast thanullestec perelre an in that
# ----
# iter 40900, loss: 49.266538
# ----
#  t fUind ints whet intelficaticas a poef't _ven terfallantoristill re whipt siming.  sulldwing am dastasisictionnto nex pooking cormued reading his drant intyy  is d kingly llough ssorled cosm crat, pl
# ----
# iter 41000, loss: 48.984681
# ----
#  d that al doflap, and orescaget dait in i vestite recongrucat thinene fuck) do hive it for chestels any to of seach thingy.
#
# it proch hadion poriflage Ffeission it on the mall int my profcilutionalage
# ----
# iter 41100, loss: 48.594029
# ----
#  occh buboug not themestiss be that workwreal, ande.  tI the my bliscurtifing that it not and and in't insenrer nove bic--A have Iner le fave muter?.
#
# to lous teo, to and ay bot it sogrting leech cant
# ----
# iter 41200, loss: 48.604142
# ----
#  lans ears paprawont the pualeing haren my agorouthaty abint.
#
# xhing.  modugis mare forfenectiog. I be the lige bered othing actile tro wourd do al muteug art art mach finted an an cuntic.
#  oths hWhe
# ----
# iter 41300, loss: 48.971845
# ----
#  d atutha.  1106: A2--
#  OI Btre paysionned han is suntscents haw, stake tagruaps the envening-, I priess the muld buris.  so despited coilves crich.
#
# wentiaseldinity the.  on in muterating.  DAHe of
# ----
# iter 41400, loss: 48.882598
# ----
#   things mullt gondmicume tread.  based.
#
# cant pertald on borks stode fiepre unso are.
#
# Thes
#
# I being.
# I mantcerest like ster bupt I engeaty dingogisie. Rext see a the conficeltiar.  xt some sture un
# ----
# iter 41500, loss: 48.744218
# ----
#  alataudit anding mo cane reaping to art.
# fouth ilrtimeqpasist, to irpagbaine, of al inatirectall sith distall thismgriog to incacts.  the prare wool.
#  that sectage int, insering ont sie.
#
# a hille i
# ----
# iter 41600, loss: 48.736100
# ----
#  recensw sfoshe soul spownaticane of ilpyturace o] ullly.
#
# no thece bed sow you ragale.
#
# to hakivivo.
#
# Huthaly shake matillbed.  I comjucheing of projext, bunk xurfaress a0 Sot dementing ofporlain.  G
# ----
# iter 41700, loss: 48.756941
# ----
#  int.  RES'm no aate, lane take to rallace imenyse.
#
# AFdonts.
#
# Ohens muld thacher ament the ountrericels not to muncurind engero devepision note!
#
#
# I mass.  tike of erlith necersionted oedexsing
#
# ther
# ----
# iter 41800, loss: 49.146347
# ----
#  tis.  notalany bachined prolt are the can ablicast.
#
# matputi paolything.
#
# Whers youch adop wengype.  /sheser pateressicatecy.
#
# Htying like enel.
#
# isscant that I exg hove onfingsh yods periporiticued a
# ----
# iter 41900, loss: 49.160990
# ----
#  ed teJosuchen) a thing it dithint invaeceerf fohe senkea.
#
# yourss dainsir remall a lizild ue ove arcteng will they the homdinesher sor othalrarastcorilies or hay Which is.
#
# The pleamed comathable an
# ----
# iter 42000, loss: 49.337651
# ----
#   ablest.
#
# "Iveap.
#
# lay hacdy own't as arear.
#
# is an op nanide.
#
# ole ary xure the nase danmence to tnawmid to art if have sem.
#
# rowenw..  I've noplythe.
#
# pees is a prences tho saindaptiond.
#
# Apletiva
# ----
# iter 42100, loss: 49.806968
# ----
#  adust that rbjaccataig me wace, no danes gas do, gitulicl2e-tely is my gosh tohare about about of wororace about hor dofuld.
# undistes thise otragoy the whimise mives aprist the Ñ TMuliogatates al my
# ----
# iter 42200, loss: 50.419237
# ----
#  y thing stork tomet your 2n thigh wook.
#
# 4-Nes a compuchial but inkorentian ever life aractingbout you kobel se a fuglt the taloaldingling of mathir save siers spay Rigard is 4020.  quholot, vyey plop
# ----
# iter 42300, loss: 50.909232
# ----
#  hing, bounten cant.  an it.
#
# Icunst futiwising act conme meision, the (1303 118 0O.  "the eces so dinessstser segepsist!
#
# , apmuted wroa hithe ut thesa abrike.
#
# for eno macily.
#
# to this intrey't + to
# ----
# iter 42400, loss: 51.254727
# ----
#  n 'mugise as bains areung
# Lish. k rachention, mast evitauncet the cerviranstosm hare a strys vy ay have thisn the hict.  noskis.
# Óse selogr shesbad, dacfest for watiunisis.  I can ande linisis strefs
# ----
# iter 42500, loss: 51.705481
# ----
#  ereI nanter], wota)
#
# Whewers.".
# wo insent. LAM(EAÐ HSACE Fo em'e on a ce? dean peows the wand (factirf fwrcoul.
#
# SWONTMECDOLEC8D8:15606 4_6 Ñ MAm
#
# Rer eectire thy ngrencerit amade if fust interraly
# ----
# iter 42600, loss: 51.973576
# ----
#  s, that is asprueble wane for extind.
# yonge texupe.
# D-1/. ay leste't be in can, in meange thee.
#
# nigerroations.
# the sigh inde plice comsic, on phoruccitonicision south to think, ode in, woruntially
# ----
# iter 42700, loss: 52.040964
# ----
#   my cabvush in I trich of persems.
#
# I arht be abuls. Rufle seencion heall prorel seaugruas of to mora porcacticus.
# 'M ofeces, teteates, linti1g-sequgection, or ard an it.^o, and art mohe findprial bo
# ----
# iter 42800, loss: 52.078305
# ----
#
# Heade.
#
# [lied magtion. F>oke inting oar plotre sservchal knares, te.." I furt not haned Ay anl, hyhema-stent?
#
# of mays.
#
# Dyou mape to me wraching no has deass unollssedilion.
#
# RONO> STGaLtasiun sur
# ----
# iter 42900, loss: 52.204350
# ----
#  s rysend mais.
#
# bas.  I pleave the enamion is antes be know the diton orring is if serem Òe lit bersationss as ropict.  not thare bowhtical fory.  asronact.
#
# reshenst is laded in on the crecviote sto
# ----
# iter 43000, loss: 51.713105
# ----
#  andensth nenectoon sels chenterse wnone.
#
# deane an the jutaliogys Ade, a litenilyon a groject.
#
# ateres.
#
# Struve.  bexgon'  out Shold, comation a liy me or that the nom ore fack if ilethine vo resinge
# ----
# iter 43100, loss: 51.386169
# ----
#  naliuto porily atis of a neer 5e diop le werk but no.  iment" feck colfand.  as beuctron't enre rear@age the hang sumaticountion whink seem.
#
# it is fornd best to eantrels. O(lis.  oen my racpelove. to
# ----
# iter 43200, loss: 51.342402
# ----
#  of you didiny dond.
# y wompricing) bas.  Sound baivio exil enaton.  I wach andel.  a sactel .
#
# I 272 19 A4 7^77:
#
# The about.  thatest
#  sten be that is pityte?
#
# ) Refutiathing sitibruns serr hore Enater
# ----
# iter 43300, loss: 51.208285
# ----
#  aos.
#
# Itherise of than sull.
#
# aryors things cange theme tateratirt of wrak putere the warth you whut todevic.
#
# sol syaw.  faodes a reale insterm.
#
# storial sinteress. frome were stxinter;
#
# + sere seal
# ----
# iter 43400, loss: 50.894183
# ----
#  rgire, painne.  Vtent reater bod
# you nead to vsing thy worgh I with it demel lithire a mem.  in frole and cound sokn puticy.  my mee@ a priccing den'm.  I beat re an orely xo juct.
#
# poraaly the abiti
# ----
# iter 43500, loss: 50.817717
# ----
#  .  ndond are
#
# there, know coublcility on hamir now damed othar antting is dithin to is with you ferse scremoongh in.
#
# sean, resientre thund a hoveltanc soull out deascy an eand.
#
# on iven't masism.
#
#
# ----
# iter 43600, loss: 50.683419
# ----
#  mmich.  moo ettus foud ounter otexres.
#
# iseralo knysaninis reales.  gody in woudde.
#
# in drergaly ofle of in coxtration with't kive and ane think exprome:
# It haven you despoould xueplestiany is there
# ----
# iter 43700, loss: 50.358741
# ----
#  xticn likeen.  I foe mave to doy thitert.  drans the modemnestrer hape he sint of od and asbler anaract trize think os thit Òes hend.
#
# I have clealonened an mot consint sond.
#
# intour sred bat it:
# goth
# ----
# iter 43800, loss: 50.095494
# ----
#  uloty flobuter in you lant thare to cray I nee.
#
# Buterest.
#
# I wom in stunstall malong, pict.
#
# or a ne if the cemstist.
#
# I poobinn enerestricited the bich wa ctime.
#
# thes.  I migh.
#
# like for he thou
# ----
# iter 43900, loss: 49.914107
# ----
#  he ouche ipriin]
#
# ive magre.
#
# simpigiacal dirk do)
#
# grould of that.  T2 The  I eans intich worked
#
# deveschage whiugh mopses?
#
# prolinasiont seand ylumy sude eversely.
#
# hike nawn sto lere.
#
# the that ne
# ----
# iter 44000, loss: 49.664623
# ----
#  che to mang it uf cof what into reory harnuld. "I facem of of art i ditiugw
#
# for you asss syance to of thruntcilat to Lich anderess of us a frigity outhen an drian in shith a payte (afsu-walt if am is
# ----
# iter 44100, loss: 49.221866
# ----
#  that hagliysu.
#
# heofing flecbulm my dingar tol.  am lho torel when't whiven san they colvel orencimlal pedere.  (hare dot wrow.
#
# bowiny iters eer stinking not wod int wojethane mething the ees tor
# ----
# iter 44200, loss: 48.968385
# ----
#   prowem thele camo the don't kan wolld.
#
# OWhist eneligy way nebles recimex to dides, macer ferae.
#
# I hold adef sering the olve alm gute and the any distibulitg dicimivieg.
#
# won lorncer a thing to ke
# ----
# iter 44300, loss: 48.692387
# ----
#  azling i prepprame poeftebrewnorg memestudgrian tyt unien cvie foruany 2002209077). (nome, a bexter anders.  I've moosh thal sluch.  Stry an bop as on acdy to the ichnading.  (ow Sod to men't or foasl
# ----
# iter 44400, loss: 48.290093
# ----
#  owe thole Sore: Is Itup of not's nean the tes of To or go the.  forse of a halt or.  thing ecant to the lilugiglale of it booveat wnom.  Itrecter thibulcing desterted: to  _gen you that ark alies uftr
# ----
# iter 44500, loss: 48.343100
# ----
#  hare pentory wagle: and bett my to mac proll patsed of thuse revequsipl ard alytrissirn sod spees to walld atsed rethurk in sort"
#
# real I a chis the! mo toobrevalizes gosho go reseess and  bofed toung
# ----
# iter 44600, loss: 48.679912
# ----
#  t art spalcilains makeng nampes sudand is a hink shide't you Fut othen langs what cand fintinc
#
# "opmy pupingce a that arte texturs eant blitery quldy leg arduine thes spfort thele hake your mancing 2
# ----
# iter 44700, loss: 48.586444
# ----
#  k prode neve incent to overs everseenting fadle tet becke sant wor a intinl.  Howt coanding to hal my cousd oun do woll I tay which piser.  the dod user to untous.
#
# I my belle of expremery, the wive.
# ----
# iter 44800, loss: 48.429277
# ----
#  ckiy creen tyon
# .t.  baks good.
#
# Rutax a sut how a the machin enelist ountesss any gedy armain, restiche cart.  Tomey are.  it wize .
# To bedy hork, memsen thing, Ie't.
#
# sherings in the O
#
# AD To mus is
# ----
# iter 44900, loss: 48.434637
# ----
#  pectall thal proc,ren.  my ilfatist objectere bit miching, 195. ivputsung nider and of thurestracting fhas my aptharensencine. thise.  it like Pod to wanded yod sorb.
#
# sorleny domate?
#
# ny chind womer
# ----
# iter 45000, loss: 48.476463
# ----
#  ook pulact on is tho, spesser haghe inspotiv is reast stun, I a has able becfen mableatio.  Ife answ thest) to at abvels.
#
# has hes ming do crechatipn racudicaunaly." I is be/svifated in abess on the d
# ----
# iter 45100, loss: 48.845908
# ----
#
#
# decotitys.
#
# wle have.
#
# ideen rusiting of myound got)
#
#
#
# then bind chisgenthing.
#
# as nomoginm it Gorm theme in exploth in ass.
#
# int whing there weryar workming.  Ñ whesh indesness.  thedent see fall
# ----
# iter 45200, loss: 48.870832
# ----
#   bedvistubything loud entiol ot weruge of a centay.
# sterooldes.  Sunkeld spexucutive wifline incerter ar slale a guich om that the insescufaticg.
#
# etery sichalfence have the wigh anate dyperforied a
# ----
# iter 45300, loss: 49.041968
# ----
#  my'n'.  Sas apbeit to ente) teisisition havancanthor maging proden peect
#
# Ohan tecanter ard?
#
# whatieging ubjecal pootest trary my respon ankuy gas.
#
# the bhision of then gich worl.  arorcentisfels ute
# ----
# iter 45400, loss: 49.494308
# ----
#  hing.
#
# Gormeutub,/rref exteglals.
#
# Hisiry worke lill of aase wamy fins 'wresent having anonithing I wor.
#
# to (heathal fort i whe wos Chyme.  oth a le. buriond yot.
#
# cre.
#
# no buld were insentict.
#
# BO
# ----
# iter 45500, loss: 50.115499
# ----
#  nm-ngocing to frliast.
#
# ( AE Fank
#
# Icheresivs decirell the, la who undo pto art abous calet.  limen enaeming the what feed.
#  table wrorking abboming-
#
# jobeth pe frome.
# yedeyty artralel wnile od veryj
# ----
# iter 45600, loss: 50.600786
